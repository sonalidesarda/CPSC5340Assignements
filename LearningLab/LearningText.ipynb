# %% [markdown]
# #### Classification Example:  Predict Review Score Based on Its Text
#
# * Get a sample of reviews from our Amazon data set
# * How accurately can we classify a new review based on fields different from its score?
#
# First re-cast the problem
# * Original problem is a regression problem -- predict score value
# * This often does not work in practice, the difference between 2 and 3, and 3 and 4 often cannot be predicted from the review summary and body.
#
# Quantize the problem
# * Score of 1 and 2 are "bad" reviews
# * Score of 4 and 5 are "good" reviews
# * Problem becomes a classification problem

# %% [markdown]
# ----------------------------------------------------
#
# **First steps**
#
# * Gather a set of training examples
# * Reformat them to make them ready to use with a learning algorithm
#
# The file "reviews.txt" was just sampled from the reviews collection.
#
# The full set isn't really equally balanced -- in the full set, positive is about 5 to 1 over negative -- and dealing with imbalanced classes is a real issue, but we will ignore class imbalance for this exercise.

# %%
import numpy as np
import pandas as pd

# %%
def load_training(filename="reviews.txt"):
    training = []
    for line in open(filename):
        training.append(eval('(' + line + ')'))
    return training

# %%
raw_training = load_training()

# %%
raw_training
# Out:
# [{'reviewerID': 'A007549913T3THC2E44K5',
#   'asin': 'B0046ZHQAW',
#   'reviewerName': 'Marce',
#   'helpful': [3, 4],
#   'reviewText': 'is a very good iron, your hair look beautiful and in just one pass!, does not hurt the hair! It is all I can say',
#   'overall': 5.0,
#   'summary': 'Really good one',
#   'unixReviewTime': 1366329600,
#   'reviewTime': '04 19, 2013'},
#  {'reviewerID': 'A03666331WS5WUZMM0AUD',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'Susanne Gonzalez Delgado',
#   'helpful': [3, 3],
#   'reviewText': 'Good quality for this Price. The curls gets quite tight if you have m&eacute;dium long hair. I have now longer hair and the results looks now better as the curls look more natural.The only thing I dislike is that my fingers get constantly burned, .. I guess it I am not very good at this but it would be gread if it came with a special glove to avoid this.Top product, I would definitely recommend.',
#   'overall': 5.0,
#   'summary': 'Conair Xtreme Instant Heat Multisized Hot Rollers, Pink',
#   'unixReviewTime': 1378080000,
#   'reviewTime': '09 2, 2013'},
#  {'reviewerID': 'A03898972RKS9HXS4H1F3',
#   'asin': 'B002610SB2',
#   'reviewerName': 'Nancy Denise Graves',
#   'helpful': [4, 5],
#   'reviewText': 'The shirt fits perfectly--true to size.  It is easy to care for and never needs ironing.  I will be buying more in the near future.Great buy!',
#   'overall': 5.0,
#   'summary': 'It was exactly what I was looking for!',
#   'unixReviewTime': 1358726400,
#   'reviewTime': '01 21, 2013'},
#  {'reviewerID': 'A04051149NH0IDZZ4FH7',
#   'asin': 'B002610SB2',
#   'reviewerName': 'Donnie',
#   'helpful': [4, 4],
#   'reviewText': "Wife hates hot days, well we live in florida... Keeps her nagging down to a minimum and she dosn't complain about being sweaty. Buying more for her.",
#   'overall': 5.0,
#   'summary': 'Nice shirt for the wife',
#   'unixReviewTime': 1394755200,
#   'reviewTime': '03 14, 2014'},
#  {'reviewerID': 'A06263011FDVMGFVAALWO',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'Hannah Moss',
#   'helpful': [0, 0],
#   'reviewText': "So much faster for me than using a curling iron! I curl my hair everyday, and I love these!! They're worth it!",
#   'overall': 5.0,
#   'summary': 'I love them!',
#   'unixReviewTime': 1365984000,
#   'reviewTime': '04 15, 2013'},
#  {'reviewerID': 'A099766128UI0NCS98N1E',
#   'asin': 'B006WW84TE',
#   'reviewerName': 'CeDe',
#   'helpful': [0, 0],
#   'reviewText': 'When the dogs gobble down these treats&#60; then I know they are good to the taste & they are priced right, too.',
#   'overall': 5.0,
#   'summary': 'Dogs give "4" paws up!',
#   'unixReviewTime': 1386288000,
#   'reviewTime': '12 6, 2013'},
#  {'reviewerID': 'A100HB5G1JLUJ7',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'BLTiger "jp robinson"',
#   'helpful': [0, 0],
#   'reviewText': "If you like Police drama shows, then this is it!  Old school 90's show with a great writer and many great actors.  Real life events.",
#   'overall': 5.0,
#   'summary': 'Outstanding Series',
#   'unixReviewTime': 1364515200,
#   'reviewTime': '03 29, 2013'},
#  {'reviewerID': 'A101BX7DD7EUZ1',
#   'asin': 'B000FIX1FS',
#   'reviewerName': 'firefly52',
#   'helpful': [2, 2],
#   'reviewText': 'This CD was a bargain and a breath of fresh air. A few of the songs were on a 1982 sampler LP from the record company (IRS) but with a total of 22 tracks it is an extravaganza of early songs by many new wave bands. Rather than list songs, the groups are enough to ensure any 80s post-punk and new wave fan it is worth it\'s price. Groups:  The Police, The Go Gos, Wayne County and the Electric Chairs, Wazmo Nariz, Root Boy Slim, Skafish, John Cale, Oingo Boingo (only a lad), Klark Kent (Stewart Copeland before he founded The Police), Buzzcocks, English Beat, Cramps, Magazine, Wall of Voodoo (Mexican radio), The Alarm,, R.E.M., Dr. and the Medics, Lords of the new Church, Timbuk 3, Fine Young Cannibals, Caterwaul, and Concrete Blonde. See, I told you the list was very inclusive of the period. Not very many songs are "faves" but some were very familiar from other groups.If you want a good intro to the late 70s and the new wave scene, enjoy. Note I had to list 2 early "fave songs" as a teaser...shu',
#   'overall': 4.0,
#   'summary': 'Bargain of new wave mostly rare performances.',
#   'unixReviewTime': 1364774400,
#   'reviewTime': '04 1, 2013'},
#  {'reviewerID': 'A101HTPLV9HVMR',
#   'asin': 'B00FXCWZF8',
#   'reviewerName': 'theresa',
#   'helpful': [0, 0],
#   'reviewText': 'If you love vibrant color, soft material, something that will make you stand out in a crowd....this is for you. It is very see-through. Note that.',
#   'overall': 5.0,
#   'summary': 'bright!!!!!',
#   'unixReviewTime': 1391990400,
#   'reviewTime': '02 10, 2014'},
#  {'reviewerID': 'A101MGS3CZIOED',
#   'asin': 'B001GB3ZPE',
#   'reviewerName': 'Alvaro Candanedo',
#   'helpful': [0, 26],
#   'reviewText': "There are products like these that are very limited in their applications. I bougth them because I had a flashligth that used them and I couldn't get them where I live. Now the flashligth is broken and I ended up with 6 4A batteries that I don't need.",
#   'overall': 1.0,
#   'summary': 'batteries, are batteries',
#   'unixReviewTime': 1306195200,
#   'reviewTime': '05 24, 2011'},
#  {'reviewerID': 'A102TGNH1D915Z',
#   'asin': 'B00008DFK5',
#   'reviewerName': 'LINDA Riley',
#   'helpful': [0, 0],
#   'reviewText': "When I want my dog to leave everyone alone for 20 minutes, I give her the Kong treat I prepared in advance.  A cow bone doesn't even last that long with this dog.  (You never want to be on the wrong side of those teeth!)Here's how I make it:  I put aKONG Stuff'N Snacks, Liver, 11-Ounce, Largein her Kong toy, then put the paste in around it, and sometimes I even fill it all the way up.  (With this dog, I can also put in leftover meat or fish, because she will get it all out in short order.)  Then I put it in the freezer against the day she is driving me crazy.  I don't know how long it takes to freeze, because I have never used it the same day I prepared it.",
#   'overall': 4.0,
#   'summary': 'Great distraction',
#   'unixReviewTime': 1264204800,
#   'reviewTime': '01 23, 2010'},
#  {'reviewerID': 'A1032P2ORSE8V',
#   'asin': '1841488801',
#   'reviewerName': 'MMK Irish "&#34;frugal mom&#34;"',
#   'helpful': [2, 2],
#   'reviewText': 'My 2 1/2 years old son loved this book. The pictures are great and the catchy song too.He can not stop singing the song.Great gift for a boy who loves trucks,trains,planes,etc.',
#   'overall': 3.0,
#   'summary': 'entreteining book',
#   'unixReviewTime': 1212537600,
#   'reviewTime': '06 4, 2008'},
#  {'reviewerID': 'A1035T8EUHMJ0J',
#   'asin': 'B001OOQAY6',
#   'reviewerName': 'B. Bogner',
#   'helpful': [2, 4],
#   'reviewText': "I love these shoes and I've gotten a TON of compliments on them. They were purchased to wear to my cheerleading-aerobic dance class (Cheerobix) and they work really well and give me a lot of support where my other shoes were lacking. I've worn them a few times and I imagine once they are more broken in, they won't bother my ankle-bone any more (there is a bit of rubbing, but not enough to deter me from wearing them). I wear a 10 and have wide feet, and the 10 fits great. If you are thinking about buying them, I give these shoes two thumbs up! They are cute, a great price, and they do the job!",
#   'overall': 5.0,
#   'summary': 'Rah rah RAH!!',
#   'unixReviewTime': 1362268800,
#   'reviewTime': '03 3, 2013'},
#  {'reviewerID': 'A103W7ZPKGOCC9',
#   'asin': '047140392X',
#   'reviewerName': 'rodog63jr',
#   'helpful': [3, 4],
#   'reviewText': "This book fills in the missing pages of Wall Street's History. It documents how African-Americans overcame racism and other barriers to become successful in the financial securities industry. This should be part of every business school's curriculum.",
#   'overall': 5.0,
#   'summary': 'The first and best of its kind',
#   'unixReviewTime': 1017100800,
#   'reviewTime': '03 26, 2002'},
#  {'reviewerID': 'A104QGECCAFCI9',
#   'asin': 'B00ATRD20O',
#   'reviewerName': 'A. Cohen',
#   'helpful': [0, 0],
#   'reviewText': 'Really should have no stars.  Does not work at all.  One screen comes up.  Tap it and the caption changes.',
#   'overall': 1.0,
#   'summary': 'Huh?',
#   'unixReviewTime': 1376697600,
#   'reviewTime': '08 17, 2013'},
#  {'reviewerID': 'A1055TB3B9H857',
#   'asin': 'B00005OU9D',
#   'reviewerName': 'Matt Baum',
#   'helpful': [4, 5],
#   'reviewText': "I've been a fan of Coleman stoves up until this one. As a previous reviewer posted, the shoddy construction and ultra-low quality sheet metal combine to create a product that I'm ready to get rid of. The edges are sharp, the top doesn't latch, and due to some engineering/manufacturing issue, the bottom green metal piece does not fit properly into the silver metal lip. I'm currently looking for a replacement stove because of how horribly this one is made.All that said, it does cook stuff pretty well without issue, but if it gets crushed on the car ride to the camp site, what's the point?",
#   'overall': 2.0,
#   'summary': 'Cruddy construction outweighs its functionality',
#   'unixReviewTime': 1293667200,
#   'reviewTime': '12 30, 2010'},
#  {'reviewerID': 'A105TUJSOPPXIQ',
#   'asin': 'B000OCZVK8',
#   'reviewerName': 'Nicoli E. Thompson',
#   'helpful': [0, 0],
#   'reviewText': 'My daughter picked this costume out for Halloween last year and it was a great fit.  I used it in the costume trunk for the kids, but did not hold up to multiple wears.',
#   'overall': 3.0,
#   'summary': 'My daughter loved it.',
#   'unixReviewTime': 1364688000,
#   'reviewTime': '03 31, 2013'},
#  {'reviewerID': 'A105UL54HEL0CI',
#   'asin': 'B00H46551W',
#   'reviewerName': 'l love apps',
#   'helpful': [1, 1],
#   'reviewText': 'I spend 15 min. each day on this app also my daughter. I am 38 and is having fun with this app . I hope you all get it.',
#   'overall': 4.0,
#   'summary': 'great app',
#   'unixReviewTime': 1399161600,
#   'reviewTime': '05 4, 2014'},
#  {'reviewerID': 'A106M4BO1P1QN5',
#   'asin': 'B00008DFK5',
#   'reviewerName': 'gijonas',
#   'helpful': [0, 0],
#   'reviewText': 'My dogs love this stuff.  I bought some of this and put it inside a Kong.  It kept my dogs occupied for hours.',
#   'overall': 5.0,
#   'summary': 'Great',
#   'unixReviewTime': 1382572800,
#   'reviewTime': '10 24, 2013'},
#  {'reviewerID': 'A106UF8CV5V58V',
#   'asin': 'B0006ITDJA',
#   'reviewerName': "Penni Lo'",
#   'helpful': [6, 6],
#   'reviewText': 'My 90 year old grandmother has been searching high and low for a good old fashion cotton bra. The elastic in bras chap her skin. No elastic directly touching her skin (or so I am told she is in Louisiana and I am in California) but she loves it and now her sisters are asking for me to place orders!',
#   'overall': 5.0,
#   'summary': 'My 90 year Grandmother',
#   'unixReviewTime': 1336953600,
#   'reviewTime': '05 14, 2012'},
#  {'reviewerID': 'A106XDAVKLD4IS',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'Crystal',
#   'helpful': [0, 3],
#   'reviewText': "I have not tested out this product but I have no doubts it will exceed my expectations since I've seen the product being used on other people with exquisite results! Thanks amazon!  and yes, I will be lookin' sexy! :)",
#   'overall': 5.0,
#   'summary': "lookin' sexy!",
#   'unixReviewTime': 1296172800,
#   'reviewTime': '01 28, 2011'},
#  {'reviewerID': 'A107I3WJR5I1PU',
#   'asin': 'B007J6MUH4',
#   'reviewerName': 'chen4x',
#   'helpful': [0, 0],
#   'reviewText': 'This fits perfectly!! but it may be to small to protect underneath the front seats.Also expensive!! but its custom made so what can you ask?Recommend to get both the front and back together!',
#   'overall': 5.0,
#   'summary': 'EXPENSIVE BUT GREAT!',
#   'unixReviewTime': 1363737600,
#   'reviewTime': '03 20, 2013'},
#  {'reviewerID': 'A1088FD09AJJCG',
#   'asin': 'B00920HMOQ',
#   'reviewerName': 'T DAWG',
#   'helpful': [6, 6],
#   'reviewText': 'I must admit, this was a real bargain! 5 albums in 1 download for $18.06. I\'m not crazy about "A Passion Play", but since is the Only Tull Album I do not have, I keep it to complete my collection. I like the fact that is all shuffled on the download. One of my "retirement projects" was to Digitize all of my albums & tapes. This is 5 less that I have to do.The music is great and a very good recording. Some purists may prefer the vinyl, which I can put on in a moments notice as well. While the download is 5 star, there is nothing as great as seeing JT/ Ian in concert (8 times!). Be sure to check out JT performing TAAB & TAAB2 in SF in July! See you there.T DAWG',
#   'overall': 5.0,
#   'summary': 'Jethro Tull - 5 album set!',
#   'unixReviewTime': 1361059200,
#   'reviewTime': '02 17, 2013'},
#  {'reviewerID': 'A108HBFK4QH6J8',
#   'asin': '0911921168',
#   'reviewerName': 'Rob Redmond hater',
#   'helpful': [0, 13],
#   'reviewText': "Sure, this is a fine book for advanced karate students and instructors, but with 2 copies available on Amazon.com at [...], well, for that price it should come in a solid gold binding with the author personally available for individual consultation. As it is, it looks like it was printed in someone's garage. Besides, if that folk hero to the weak of mind, Rob Redmond likes it, I hate it. I can't think of a worse person to endorse anything!",
#   'overall': 3.0,
#   'summary': "[...]? You've got to be kidding!",
#   'unixReviewTime': 1127260800,
#   'reviewTime': '09 21, 2005'},
#  {'reviewerID': 'A108QWKVBWMINJ',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'mcglom1',
#   'helpful': [0, 0],
#   'reviewText': "This was my favorite television show of all time second only to the The Wire.  Although I am not a New Yorker, I related a great dealt to Denis Franz' character Andy.  I do miss that the show is off. I miss seeing the characters each week. But now I get to see them whenever I like.",
#   'overall': 5.0,
#   'summary': 'Reason I got Amazon Prime',
#   'unixReviewTime': 1363564800,
#   'reviewTime': '03 18, 2013'},
#  {'reviewerID': 'A108UVVOASH6BC',
#   'asin': 'B008SCNCTI',
#   'reviewerName': 'Fran S',
#   'helpful': [2, 3],
#   'reviewText': 'I needed Norton 360, ordered wrong product. However, when I went to install it, I got message that it would replace a newer version that was already on my computer. I have Windows 8 on my HP computer, that had a trial version on it. Stuck for the $$$$ I spent, as I down loaded to my computer. You cannot cancel or return a downloaded order.',
#   'overall': 1.0,
#   'summary': 'Apparently not current',
#   'unixReviewTime': 1363824000,
#   'reviewTime': '03 21, 2013'},
#  {'reviewerID': 'A1091OB4GZACOH',
#   'asin': 'B00H46551W',
#   'reviewerName': 'amylia2014',
#   'helpful': [0, 0],
#   'reviewText': 'I love drawing and im good but I wasnt good at drawing dogs until I got this app now I draw them like a boss but I wish that all of them were unlocked witout having to pay for them',
#   'overall': 4.0,
#   'summary': 'cool',
#   'unixReviewTime': 1402099200,
#   'reviewTime': '06 7, 2014'},
#  {'reviewerID': 'A10BHYYEOT4ZG6',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'sharon',
#   'helpful': [0, 0],
#   'reviewText': 'what a great show this was.  even though i saw all the episodes years ago, it seems they are all fresh and new.  nostalgia is great--especially  via tv.',
#   'overall': 5.0,
#   'summary': 'memories',
#   'unixReviewTime': 1391990400,
#   'reviewTime': '02 10, 2014'},
#  {'reviewerID': 'A10BSP6FAK9H4S',
#   'asin': '1426742363',
#   'reviewerName': 'George',
#   'helpful': [15, 20],
#   'reviewText': 'Regardless of your politics or faith system this is a must read in these divisive times. Americans must learn how to have civil dialogs in the midst of competing views. Americans will learn to live together or we will tear one another apart. Slaughter, et al call people of faith especially to sit down at the table and discuss the implications of policy and faith.',
#   'overall': 5.0,
#   'summary': 'A must read in this political season',
#   'unixReviewTime': 1326758400,
#   'reviewTime': '01 17, 2012'},
#  {'reviewerID': 'A10CP3GZQ1J7FY',
#   'asin': '1581802633',
#   'reviewerName': 'Camille Rita Conchita Louise "Designer in the...',
#   'helpful': [1, 1],
#   'reviewText': 'This is the book to get you started in a hobby or career as a designer. I was struggling with getting organized and not knowing how to start, where to start, and with what to start. The book is easy to read and includes all the essentials for the basics of design. I checked it out at the library, and after reading it from cover to cover decided it was a must have, and so purchased my own copy. I highly, highly recommend it.',
#   'overall': 5.0,
#   'summary': 'A Must For Designers',
#   'unixReviewTime': 1203465600,
#   'reviewTime': '02 20, 2008'},
#  {'reviewerID': 'A10DE3O1A7LGH4',
#   'asin': 'B00005T3TR',
#   'reviewerName': 'Kathy G "8ks are too long"',
#   'helpful': [0, 0],
#   'reviewText': '(...)  It had a good picture once you adjusted the bright.  Sound quality is good. The folding makes it compact and the antenna in the strap really works, you just have to position yourself to get the best reception.  (...)',
#   'overall': 5.0,
#   'summary': 'Good TV, better price!',
#   'unixReviewTime': 1008115200,
#   'reviewTime': '12 12, 2001'},
#  {'reviewerID': 'A10E1H27GLD0MJ',
#   'asin': '0224070746',
#   'reviewerName': 'Christine Mason "Max\'s Mom"',
#   'helpful': [0, 0],
#   'reviewText': 'Love this calendar - we love the books and illustrations, so this is a wonderful daily reminder.',
#   'overall': 5.0,
#   'summary': 'Fabulous Drawings',
#   'unixReviewTime': 1168300800,
#   'reviewTime': '01 9, 2007'},
#  {'reviewerID': 'A10E29QGG5YCBX',
#   'asin': 'B00FAX6434',
#   'reviewerName': 'Janet Kelley',
#   'helpful': [0, 0],
#   'reviewText': 'Great book. I highly recommend for any chef or home cook, even kids who growing up cooking and love the kitchen!',
#   'overall': 4.0,
#   'summary': 'Highly recommend',
#   'unixReviewTime': 1384387200,
#   'reviewTime': '11 14, 2013'},
#  {'reviewerID': 'A10E5N42JSIUWA',
#   'asin': 'B00CJ0TNPW',
#   'reviewerName': 'SeesRain',
#   'helpful': [2, 2],
#   'reviewText': 'Applying the screen protector was not as easy as others I have applied.  The 2nd layer (top) released too easily before I was ready to apply and the screen protector not quite aligned with the edges.  However, the edge is covered by a protective case cover so the misalignment is not seen.The length of the screen protector was about 3/16 of an inch short at the bottom, but I think it will still protect the screen nicely since that last 3/16&#34; is not normally used.',
#   'overall': 3.0,
#   'summary': 'Screen protector is functional, but not great',
#   'unixReviewTime': 1370995200,
#   'reviewTime': '06 12, 2013'},
#  {'reviewerID': 'A10EO71X96RDT1',
#   'asin': 'B000A09DVM',
#   'reviewerName': 'jmasuk',
#   'helpful': [1, 1],
#   'reviewText': 'We only put one bait bar out after seeing multiple rats near our compost pile.  within a day the bar was gone and within a week we found dead rats.  i love this stuff!',
#   'overall': 5.0,
#   'summary': 'works great, love it!',
#   'unixReviewTime': 1307577600,
#   'reviewTime': '06 9, 2011'},
#  {'reviewerID': 'A10EVSGZXTHRPN',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'Jo Waybright',
#   'helpful': [0, 0],
#   'reviewText': 'This is the first &#34;controversial&#34; police show that was aired.  There was a &#34;little&#34; nudity in it in the first episode.  It was a gritty and moving story of what the police experience both  in their private lives and on the job.',
#   'overall': 5.0,
#   'summary': 'Broke the Ice',
#   'unixReviewTime': 1366588800,
#   'reviewTime': '04 22, 2013'},
#  {'reviewerID': 'A10F69SHVIM2C0',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'Shane',
#   'helpful': [0, 0],
#   'reviewText': 'First season of a great series. I love Dennis Franz. I recommend the whole series. Great cop drama! NYPD BLUE.',
#   'overall': 4.0,
#   'summary': 'Great show!',
#   'unixReviewTime': 1387756800,
#   'reviewTime': '12 23, 2013'},
#  {'reviewerID': 'A10FEVHZPK71QU',
#   'asin': '1581802633',
#   'reviewerName': 'Yajaira Sosa "Yajaira"',
#   'helpful': [0, 0],
#   'reviewText': 'If like me, you are not an expert on creating your own designs, this is a book that I recommend buying. It is a guide where you can get a lot out at times when you do not feel sure of what to do or how to put things together.',
#   'overall': 5.0,
#   'summary': 'Very useful!',
#   'unixReviewTime': 1338768000,
#   'reviewTime': '06 4, 2012'},
#  {'reviewerID': 'A10GI4O6O3Y0QW',
#   'asin': 'B000006NW8',
#   'reviewerName': 'Bruce Tutcher',
#   'helpful': [7, 7],
#   'reviewText': 'Listening to Zia Mohiuddin Dagar play rudra veena is like watching the stars at night. If you can contemplate all the ways that all the stars move in relation to each other, you may understand imaginatively how Dagar creates precise relationships between all the tones he plays.',
#   'overall': 5.0,
#   'summary': 'heavenly spheres',
#   'unixReviewTime': 1118880000,
#   'reviewTime': '06 16, 2005'},
#  {'reviewerID': 'A10GJQI5J4ZVUH',
#   'asin': 'B002NWXVJU',
#   'reviewerName': 'R.S',
#   'helpful': [10, 12],
#   'reviewText': 'This product was not at all what I expected and the way it was described was quit misleading. Be forewarned  this faucet is PLASTIC not metal. It was described as being brushed nickle and implies the faucet will be metal. For 60.00 dollars I was expecting a metal faucet and was very surprised when my husband said it was plastic. So far it seems to be durable and  well made , but we will see  how well this faucet functions in the long run. The description should tell you up front that the faucet will be plastic I was looking for a metal faucet and would have continued looking for another faucet had it been stated clearly that it was plastic.',
#   'overall': 3.0,
#   'summary': 'cleanflo 8814',
#   'unixReviewTime': 1368835200,
#   'reviewTime': '05 18, 2013'},
#  {'reviewerID': 'A10H3VDEPW7QWI',
#   'asin': '0140296131',
#   'reviewerName': 'John Barry',
#   'helpful': [33, 33],
#   'reviewText': "A Star Called Henry is probably far more accurate in its portrayal of Ireland in the last years of British rule than many would realise. The activities of the members of Michael Collins' &quot;Squad&quot; were much  like those performed by Henry Smart, who was, in the novel, on the  periphery of possibly the most effective counter-intellegence agency in the  world.  Roddy Doyle's excellent novel captures the period as well as  anything I have hitherto read on the subject. He captures the feeling of  Dubliners towards the Easter Rising, before and after the executions, and  the attitude of those beyond the Pale (English-controlled region around  Dublin, where the phrase comes from) to the &quot;jackeens&quot;. Henry's  delay in leaving Ireland was, I believe, not as surprising as some seem to  think. Henry had great loyalty towards Michael Collins, similar to his  feelings towards James Connolly, a debt of honour, if you will, that kept  him from abandoning him while that was unresolved. After his betrayal and  the death of Collins, he was free to leave the country. These attributes  are visible in the character of Henry Smart, and are a major influence on  his actions. His various loyalties are strong and are probably the driving  force of his life.Before A Star Called Henry, I wasn't much a fan of  Roddy Doyle the author, preferring the film versions of the Barrytown  Trilogy, but I await with anticipation the remaining books in his latest  Trilogy.",
#   'overall': 5.0,
#   'summary': "Roddy's Finest Hour",
#   'unixReviewTime': 943574400,
#   'reviewTime': '11 26, 1999'},
#  {'reviewerID': 'A10HJ1I7CQWB4D',
#   'asin': 'B0043KSIGQ',
#   'reviewerName': 'SCBHL',
#   'helpful': [0, 0],
#   'reviewText': 'This is a Charlie Sheen look a like bowling shirt and its decent quality.  I do recommend it as there were no problems with it.',
#   'overall': 5.0,
#   'summary': 'Nice',
#   'unixReviewTime': 1355270400,
#   'reviewTime': '12 12, 2012'},
#  {'reviewerID': 'A10IEX983L1GXT',
#   'asin': 'B0006ITDJA',
#   'reviewerName': 'Rosina Pineda',
#   'helpful': [1, 1],
#   'reviewText': "These bras do not keep their shape too well.  They are certainly breathable but that's about it.  Wouldn't buy these again.",
#   'overall': 3.0,
#   'summary': 'Not too crazy about them',
#   'unixReviewTime': 1361923200,
#   'reviewTime': '02 27, 2013'},
#  {'reviewerID': 'A10J9HOYTZNS4A',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'amazon user',
#   'helpful': [0, 0],
#   'reviewText': 'One of the best seasons.  Groundbreaking at the time, fun to watch again.  Early career appearances for a number of now familiar faces.',
#   'overall': 4.0,
#   'summary': 'NYPD Blue classic',
#   'unixReviewTime': 1390780800,
#   'reviewTime': '01 27, 2014'},
#  {'reviewerID': 'A10JAUL2CEPNL2',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'Joseph L Maloney Jr.',
#   'helpful': [0, 0],
#   'reviewText': "Didn't get in to this show until Smits joined.Loved chance to start show from beginning planning on watching entire series.Excited about watching characters grow in a compressed time frame.",
#   'overall': 5.0,
#   'summary': 'great show',
#   'unixReviewTime': 1365897600,
#   'reviewTime': '04 14, 2013'},
#  {'reviewerID': 'A10JFRVQCYQTP2',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'vice7600',
#   'helpful': [0, 0],
#   'reviewText': 'i love this show i never got to see the last season and i love that it on prim if you have never watch this show then you should',
#   'overall': 5.0,
#   'summary': 'i love this show',
#   'unixReviewTime': 1373587200,
#   'reviewTime': '07 12, 2013'},
#  {'reviewerID': 'A10JNGBPFY2DZM',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'KatinCharleston',
#   'helpful': [0, 0],
#   'reviewText': 'Great to see the show again (uninterrupted).  Almost through season 1, and looking forward to season 2.  Miss Dennis Franz, since he retired.',
#   'overall': 4.0,
#   'summary': 'As good as it was the first time!',
#   'unixReviewTime': 1377734400,
#   'reviewTime': '08 29, 2013'},
#  {'reviewerID': 'A10K7FH7CS1GV3',
#   'asin': '1481989103',
#   'reviewerName': 'EHS Director',
#   'helpful': [0, 0],
#   'reviewText': 'Robert Hall\'s latest book takes us through the basic concepts of protecting individuals from the pitfalls of our current society.This book is a commonsense guide for a world devoid of it.Mr. Hall\'s perspective and broad insight is a welcomed and refreshing change over the typical main stream "self help" guides and 12 step programs that focus on "protecting  feelings" rather than personal safety, self reliance or the actual prevention of problems.Mr. Hall offers simple solutions to protect individuals from both financial and personal harm while adding a little humor and personal lessons from the perspective of former state Senator and Veteran.In a world where fathers, family, faith and commonsense are in short supply, Mr. Hall offers us all a plan to be safer and keep life on the right track.',
#   'overall': 5.0,
#   'summary': 'This book is a commonsense guide for a world devoid of it.',
#   'unixReviewTime': 1370995200,
#   'reviewTime': '06 12, 2013'},
#  {'reviewerID': 'A10K7IYEPRP9JZ',
#   'asin': '1892165082',
#   'reviewerName': 'John C. Leach',
#   'helpful': [0, 0],
#   'reviewText': "I am familiar with many of the prophecy's in this book. She did expand my understanding of the times we are living in. Her writing was very informative, I would be interested in any of her writings.",
#   'overall': 4.0,
#   'summary': 'Great book',
#   'unixReviewTime': 1364428800,
#   'reviewTime': '03 28, 2013'},
#  {'reviewerID': 'A10KSG1TECC05V',
#   'asin': 'B00EP6OTC0',
#   'reviewerName': 'Jo can soar like a eagle',
#   'helpful': [0, 0],
#   'reviewText': 'Now every man in the world need to listen to this song! This is such a true and prevalent song! This song needs to go viral!',
#   'overall': 5.0,
#   'summary': 'I pray the World hear this song!',
#   'unixReviewTime': 1384992000,
#   'reviewTime': '11 21, 2013'},
#  {'reviewerID': 'A10LT5W0664V40',
#   'asin': '0375867139',
#   'reviewerName': 'Audrey Kadis',
#   'helpful': [0, 0],
#   'reviewText': "Although Beatrice is only 10 months old, it's never to early to prepare a child for the potentially daunting task of babysitting Grandpa.  It cracks me up and is educational for her ...a win-win",
#   'overall': 5.0,
#   'summary': 'For my granddaughter',
#   'unixReviewTime': 1369353600,
#   'reviewTime': '05 24, 2013'},
#  {'reviewerID': 'A10MVE2MEOU6XT',
#   'asin': 'B002YLEPP4',
#   'reviewerName': 'Julie Schmidt',
#   'helpful': [7, 7],
#   'reviewText': 'I love popcorn seasoning, but they all mostly taste like salt.  This one tastes like white cheddar!  Imagine that.  I will never order the other kind again.',
#   'overall': 5.0,
#   'summary': 'Finally tastes like Cheese and not Salt!',
#   'unixReviewTime': 1297728000,
#   'reviewTime': '02 15, 2011'},
#  {'reviewerID': 'A10N19OL0CKYDV',
#   'asin': 'B001T8OD9Q',
#   'reviewerName': 'Erica',
#   'helpful': [1, 4],
#   'reviewText': "The only thing I dislike about this product is the name: Dry KwikIt works wonderfully as a quick drying top coat. When I'm done painting my nails, I just put a little of this stuff on each nail. It is thin and oily, and you don't have to worry about it getting on your skin (although, it does dry out my cuticles). It almost instantly dries my freshly painted nails to a glossy finish. Like another reviewer said, I believe this 'dry' is superficial, and I wouldn't necessarily push down on my nails after applying this product. However, it allows me to continue to do things without messing my nails up.It is responsible for that finished, high gloss look. It makes such a big difference that I wouldn't think of doing my nails without this product.I highly recommend it.",
#   'overall': 5.0,
#   'summary': 'Great Product, Bad Name',
#   'unixReviewTime': 1356912000,
#   'reviewTime': '12 31, 2012'},
#  {'reviewerID': 'A10N87M2QB2ZOK',
#   'asin': 'B0001DU3SK',
#   'reviewerName': 'snazzygirl',
#   'helpful': [1, 1],
#   'reviewText': 'I was very pleased with how quickly this item arrived and how it arrived in excellent condition.  While I have not yet completed the stitchery, I know it will be a nice addition to my kitchen wall.  The seller did an excellent job in filling my order.',
#   'overall': 5.0,
#   'summary': 'Excellent Service',
#   'unixReviewTime': 1350000000,
#   'reviewTime': '10 12, 2012'},
#  {'reviewerID': 'A10OWSZHEPVF78',
#   'asin': '1581802633',
#   'reviewerName': 'Frannie',
#   'helpful': [11, 11],
#   'reviewText': "Michelle Temares' &quot;How to Design your Own Painting Projects&quot; is truly a wonderful book from the beginning to the end. When I ordered the book, I really didn't know what to expect, since it's the first of its kind on the market.  Beginning and advance artists/designers will come away with new ideas and inspiration for their own artwork.Michelle Temares helps the artist/designer to see &quot;What is Good Design&quot;, &quot;Composition&quot;, and provides inspiration for &quot;Developing a Color Scheme&quot;.  Before I purchased this book, I would of never thought about using Graph Vellum (Chapter 1, Design Supplies) for designing and now that's all I use to create my own artwork.I give this book a &quot;5&quot; star rating and everyone that purchases this book will learn something new.  Michelle Temares has proven that anyone can be an artist/designer through this remarkable written book.",
#   'overall': 5.0,
#   'summary': 'Much More than an &quot;How to Book&quot;',
#   'unixReviewTime': 1064880000,
#   'reviewTime': '09 30, 2003'},
#  {'reviewerID': 'A10P0BX64HLW7H',
#   'asin': 'B00004U5R1',
#   'reviewerName': 'GV "GV"',
#   'helpful': [6, 8],
#   'reviewText': "I bought this as a Christmas gift for my 5-year old who had tried out a few scenes at Disneyland's Innoventions exhibit. Overall, she enjoyed the game and made her way through the scenes with just a little help. The programmers could have made the interface a bit better, though. The &quot;hot zones&quot; (where the pointer changes to allow for an action) are a bit small for some items so it gets difficult to position the mouse over an object to pick it up. Sometimes the pointer doesn't change at all. The system requirements are a bit high and we got just a &quot;good&quot; performance on my child's 300Mhz PII with a 32x SCSI CD-ROM. There are a number of bugs that we found as well. Mickey starts slanting at a 45-degree angle at the pond if you have him repeat a few actions. Music cuts out intermittently at a few scenes. There's also a problem with some earlier revisions of this game and it won't load if your system date goes past 12/31/2000 (a fix was posted to the [...] website recently). Overall, this was a decent try but I'd hope that Disney Interactive does a better job next time. I saw the earlier reviews and they seemed split 50-50 between &quot;fantastico&quot; and &quot;thppth&quot;. If you think you're PC-savvy enough to deal with these bugs and if your system has the horsepower, this program won't be excessively problematic.",
#   'overall': 3.0,
#   'summary': 'Not too bad but still buggy',
#   'unixReviewTime': 980121600,
#   'reviewTime': '01 22, 2001'},
#  {'reviewerID': 'A10P2PXTFJMSG1',
#   'asin': 'B00005OU9D',
#   'reviewerName': 'dj masturbeat "dj masturbeat"',
#   'helpful': [2, 6],
#   'reviewText': "So I bought one of these back in about 1999 or 2000.  Thought the Coleman name would mean something.well, if by something, one means faulty o-rings that leak from the gas canister and explode, then, yes, Coleman is your brand.this was on the very first usage, too.seriously, it is a good thing I tested this on my parent's back deck, a bit off from the house, prior to taking it out camping.  Forest fire would have put a damper on things a bit.so, yeah, unless you like exploding bombs of gas canisters and fires requiring full sandboxes to put out, avoid like the dangerous pile of crud it is.  I imagine that it has only gotten worse, cheaper in intervening years, much like everything else with planned obsolescence.",
#   'overall': 1.0,
#   'summary': 'Buy Only if You Want to Get Blown Up',
#   'unixReviewTime': 1387756800,
#   'reviewTime': '12 23, 2013'},
#  {'reviewerID': 'A10Q9Y97YMDAJG',
#   'asin': 'B0077IQSZE',
#   'reviewerName': 'Lordshane',
#   'helpful': [0, 0],
#   'reviewText': 'This fits great into my kraken case replacing the blue skin for a new look. I really like the orange color which isnt available in the kraken model and it really protects my phone',
#   'overall': 5.0,
#   'summary': 'great case',
#   'unixReviewTime': 1360281600,
#   'reviewTime': '02 8, 2013'},
#  {'reviewerID': 'A10QKW05SIP2EN',
#   'asin': 'B006O1MEU8',
#   'reviewerName': 'alexander D',
#   'helpful': [0, 0],
#   'reviewText': 'having enjoyed the bar ,the Bellinis , the carpaccio , the low key elegance of this place all captured in the understanding of the Roots and the Reality of a special place, delightfully portrayed in the book . easy to read and quite absorbing . First Prize visit the famous place, or read the story. with all its lessons of passion for serving people and adding real environment entertainment and great simple eating.. whetted my appetite for a revisit in the future.',
#   'overall': 4.0,
#   'summary': 'ah Harrys bar a true destination .',
#   'unixReviewTime': 1401667200,
#   'reviewTime': '06 2, 2014'},
#  {'reviewerID': 'A10QU04HJ88T6P',
#   'asin': '0895770261',
#   'reviewerName': 'Kim Monk',
#   'helpful': [102, 103],
#   'reviewText': 'This edition of the Complete Guide to Sewing has recently been updated.  However, the newest version does not include any information on tailoring.  I use the older version for teaching sewing and constume construction classes, tailoring and special topics classes.  Pictures and sketches are clear and written directions are easy to follow.  This version does not have much serger/overlock information but does cover many other seam finishes.  Information on fit and pattern alterations is very clear.  Beginners or advanced seamstresses will find this book a &quot;must&quot; for their reference collection!',
#   'overall': 5.0,
#   'summary': 'A &quot;Must Have&quot; for your sewing reference books!',
#   'unixReviewTime': 1015718400,
#   'reviewTime': '03 10, 2002'},
#  {'reviewerID': 'A10QXSHMYDOJVM',
#   'asin': '0201710501',
#   'reviewerName': 'Amanda Johnson',
#   'helpful': [1, 1],
#   'reviewText': 'This book was required reading for my graduate-level foundation Java class.  Having no previous experience in object-oriented programming, I was reassured by the title that Java Gently would ease me into the programming world.  While the road wasn\'t as "gentle" as I had hoped, the book does provide readers with practical examples for implementing Java 2 and explains how concepts used in introductory programs can be applied to more complex ones.  Although Java Gently is an introductory book, it would be more useful for someone who has programming experience in another language. Perhaps then the learning curve would be a bit more "gentle."',
#   'overall': 3.0,
#   'summary': 'Java Not So Gently',
#   'unixReviewTime': 1036281600,
#   'reviewTime': '11 3, 2002'},
#  {'reviewerID': 'A10RZH1O4S3TTW',
#   'asin': 'B00005OU9D',
#   'reviewerName': 'Jumpin Jack Flash',
#   'helpful': [0, 0],
#   'reviewText': 'I bought this in case the power goes out.  A friend or ours has been bringing his to our tailgate for 7 years and it works great so when I saw it on sale I had to get one',
#   'overall': 5.0,
#   'summary': 'GREAT Little Stove',
#   'unixReviewTime': 1388880000,
#   'reviewTime': '01 5, 2014'},
#  {'reviewerID': 'A10S8JTRCL7BR',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'GEORGINA POLONI',
#   'helpful': [2, 2],
#   'reviewText': 'First I purchased a very similar item but that did not have the on and off switch up front. I am glad that I returned that and ordered this instead. Also, the rollers are great but I dont use the clips hot rather cold eliminating the clipmarks...',
#   'overall': 5.0,
#   'summary': 'Excellent product',
#   'unixReviewTime': 1360627200,
#   'reviewTime': '02 12, 2013'},
#  {'reviewerID': 'A10SE8PPWLX18S',
#   'asin': '155546713X',
#   'reviewerName': 'Mrs. Kitty',
#   'helpful': [3, 3],
#   'reviewText': 'This book is very special to me. The first picture in this book, is a picture of my great-great grandmother. This book talks about the belief that the Lumbee Indians are a combination of Indians and the Lost Colony of Roanoke, which I find interesting. It also talks about the difficulty they had to go through.',
#   'overall': 5.0,
#   'summary': 'The Greatest Find I Could Ever Find',
#   'unixReviewTime': 1090627200,
#   'reviewTime': '07 24, 2004'},
#  {'reviewerID': 'A10T2H6N4BDQ7I',
#   'asin': 'B0063NHLJQ',
#   'reviewerName': 'Rachel D.',
#   'helpful': [6, 6],
#   'reviewText': "So I read a lot of reviews before I bought a new coffeemaker. We loved our old one and hated to get rid of it but a part broke that couldn't be fixed. This one does look attractive. I don't like that I have to pull it out from under the counter top to fill it with water. So far I like the carafe, it seems to pour without spilling. Pouring the water into the receptacle in the back is tricky with the last bit of water, it tends to get into the grounds part and leak down onto the heating element. Its most annoying feature: you can't turn the warming plate back on to keep coffee warm.  There is no way to keep the coffee warm without running a new cycle of coffee. And the clock can't be set going backwards so you have to push the button down over and over for each minute, and if its 12 hours off, it takes forever to set it. Annoying. The time delay brew feature is nice. The permanent filter has been easy to clean. It is a pretty noisy machine when it brews but I don't mind that at all. Its part of the coffee experience. I do like the blue display light and the stainless steel look. The coffee it brews is ok. I made it pushing the strong brew button tonight and didn't see a difference. Its an ok machine. If you have low expectations about bells and whistles you will like this one.",
#   'overall': 3.0,
#   'summary': 'A good basic no frills coffee maker',
#   'unixReviewTime': 1343001600,
#   'reviewTime': '07 23, 2012'},
#  {'reviewerID': 'A10TIBT40AKR6V',
#   'asin': '0201886782',
#   'reviewerName': 'Keith Winter',
#   'helpful': [3, 3],
#   'reviewText': 'As a web designer I have found this book to be most inspirational. While I do not agree that all of the sites that he lists in the book are designed well, it does provide many examples of various types of web sites with beautiful pictures and site layouts.',
#   'overall': 5.0,
#   'summary': 'Great Inspiration',
#   'unixReviewTime': 947980800,
#   'reviewTime': '01 16, 2000'},
#  {'reviewerID': 'A10U57A32HRQE3',
#   'asin': 'B0030XXH1S',
#   'reviewerName': 'STOAK "soffak"',
#   'helpful': [57, 74],
#   'reviewText': "Of all the headphones I have tried these produce these produce the best sound/noise canceling combo although I am not a sound aficionado. They are amazing on a plane with the exception of voices. Stewardesses, pilots and other passengers can be heard easily. I suppose it could be a good thing but I seem to prefer my old cheap Sonys to these as they cut out all exterior sound. Music and movies don't sound nearly as good but keep out 90%of all sound.They don't work unless the noise canceling is on (they have to be powered up to listen to them).  I find that while at home I would like to listen without noise canceling so I can listen for the phone, the doorbell etc. In a quiet environment I am not sure why they need to be on either. In any regard, it would be a pain to run out of juice on a plane trip as it may be difficult or impossible to recharge the battery and one would no longer be able to use their headphones. This is doubly bad since the batteries are proprietary. One would have to buy an extra set from Bose to guard against this possibility.The batteries seem to last a very long time (not sure how long but I left them on for at least 18 hours and they lasted another 1 or 2 with power remaining before charging). While these headphones are probably too nice to take backpacking or climbing it is not even an option for me as the battery could not be recharged. My preference would be to use AAA batteries. In my mind, it would be preferable as I would not have to worry about loosing a proprietary battery or charger and in the case of a long trip would not have to worry about the batteries running out.I have had several Bose products and I find that Bose does not play well with others. They often have proprietary connections etc. so that a consumer is locked in to Bose (I have also never had a lot of luck with their customer support although in their defense I always wanted their systems to work with other systems and they had little interest in that - they may be great with returns and service). These headphones appear to be the same. The cord to the headphones unplug from the headphones but the jack in the headphones seems to be an odd size. We have many headphones for our family and all the other cords are interchangeable. Not the QC3s. Probably not an issue but it may be that to replace the cord one would have to buy from Bose. In our house that may become an issue.The case that comes with the headphones simply stinks. The quality of the case seems fine but the headphones don't sit easily in the slots provided. If not placed precisely , the padding gets smashed and is uncomfortable for an hour or so (the padding comes back to form eventually).  I found an old case for another set of headphones that I use for travel and keep then in a drawer without a case at home. Small gripe but it seems bizarre to provide a case this well made for headphones this expensive that works poorly. Its like they had a bunch of cases for other headphones laying around. Rather than design a case for these headphones they simply used the old ones or share a case with other headphones they sell.These headphones were a gift. Before owning them I would have never considered buying them as my experiences with Bose have generally been bad (never the quality of the product, just that Bose will do everything they can to make sure you can only use their products when expanding a system etc.). Considering the other noise canceling headphones I have tried I would probably buy them anyway. They are comfortable, produce excellent sound and the best on the ear noise canceling I have found. My gripes are minor compared to that. If I found comparable quality in another set of headphones I would recommend them over the Bose QC3s. Given the choices I have seen I would recommend considering them if the gripes listed above are not big problems for you.",
#   'overall': 4.0,
#   'summary': 'Great sound, great noise canceling, the rest... not so great',
#   'unixReviewTime': 1294963200,
#   'reviewTime': '01 14, 2011'},
#  {'reviewerID': 'A10VCSMSU93K2K',
#   'asin': 'B000K50KW8',
#   'reviewerName': 'Audrey A. Rochester "Customer Satisfaction"',
#   'helpful': [1, 1],
#   'reviewText': 'great buy.  it looks nice and it works perfectly.  easy to clean and assemble.',
#   'overall': 5.0,
#   'summary': 'good buy',
#   'unixReviewTime': 1190592000,
#   'reviewTime': '09 24, 2007'},
#  {'reviewerID': 'A10WEPPIZW1DTL',
#   'asin': 'B0063NHLJQ',
#   'reviewerName': 'Arlene Antle',
#   'helpful': [0, 1],
#   'reviewText': 'Your service was exceptional and the product was exactly what I wanted.  I will order again with great confidence.your whole procedure was easy especially for me (a senior,somewhat electronically challenged)THANK YOU',
#   'overall': 5.0,
#   'summary': 'OSTER12 -CUP PROGRAMMABLE COFFEE MAKER BVST-JBXSS41-STAINLESS STEEL',
#   'unixReviewTime': 1378598400,
#   'reviewTime': '09 8, 2013'},
#  {'reviewerID': 'A10WL2FNJKO3Q3',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'Laura Ahern',
#   'helpful': [0, 0],
#   'reviewText': 'My memory of his performance was spot on. He rocked the show. Thus my opinion of his work on CSI:Miami stands....he is horrible!I am enjoying the journey from 1993. Cigarette smoking everywhere. Lack of technology. And amazing acting. Great show.',
#   'overall': 5.0,
#   'summary': 'caruso',
#   'unixReviewTime': 1396569600,
#   'reviewTime': '04 4, 2014'},
#  {'reviewerID': 'A10X1201RQESLQ',
#   'asin': 'B005H86LZ8',
#   'reviewerName': 'Crlyn',
#   'helpful': [9, 19],
#   'reviewText': 'This device is much smaller than I expected.If you have thicker framed glasses or sunglasses, they might not fit into this device. Also, I do not wear it next to my laptop due to the magnets. Could also demagnetize strips on credit cards that you might be carrying in your pocket (or purse). See warning on package! Needs to be twice as big as it is!',
#   'overall': 3.0,
#   'summary': 'This was featured on the TV show "Shark Tank"',
#   'unixReviewTime': 1330128000,
#   'reviewTime': '02 25, 2012'},
#  {'reviewerID': 'A10XS0YQUBE6WG',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'Emlee',
#   'helpful': [0, 0],
#   'reviewText': "The stupid clips they supply leave large dents in your hair.  I also didn't feel like they got hot enough to do anything.  I have very little curls and a huge dent.  Don't buy this one!",
#   'overall': 1.0,
#   'summary': 'Dent in my hair',
#   'unixReviewTime': 1320537600,
#   'reviewTime': '11 6, 2011'},
#  {'reviewerID': 'A10YVQ3BW5MOKX',
#   'asin': 'B00007M0CP',
#   'reviewerName': 'M. Al Suwaidi "MAMO"',
#   'helpful': [9, 10],
# ...
#   'overall': 5.0,
#   'summary': 'Excellent Detective Series',
#   'unixReviewTime': 1386201600,
#   'reviewTime': '12 5, 2013'},
#  {'reviewerID': 'A1FGYV7EKFZJLC',
#   'asin': '1499371322',
#   'reviewerName': 'Carol Thygesen "Carol5814"',
#   'helpful': [0, 0],
#   'reviewText': "This novel explores the intensity of young love and the ramifications of life's choices.  The story is told in alternating present-day and flashback chapters, which brought the emotions  and motivations of the characters into clear focus. I loved it.",
#   'overall': 5.0,
#   'summary': 'A compelling read',
#   'unixReviewTime': 1397692800,
#   'reviewTime': '04 17, 2014'},
#  {'reviewerID': 'A1FH2TV5N2G3VK',
#   'asin': '1493696777',
#   'reviewerName': 'J. Minkman "minkie"',
#   'helpful': [0, 0],
#   'reviewText': "A worthy conclusion to this awesome trilogy! Especially the end had me on tenterhooks. I couldn't put this book down. Hopefully the two extra novellas will be out as paperbacks at some point, too, because I'd like to have everything in this series in paperback format. I'm knocking off one star because there are a few too many typos in this book - it should have been edited properly before publication. And since I bought the paperback edition, I'll be stuck with those typos forever...",
#   'overall': 4.0,
#   'summary': 'worthy conclusion',
#   'unixReviewTime': 1398211200,
#   'reviewTime': '04 23, 2014'},
#  {'reviewerID': 'A1FHO6NN5UJ9F5',
#   'asin': 'B008SCNCTI',
#   'reviewerName': 'L. Mims',
#   'helpful': [0, 0],
#   'reviewText': "After years of bashing Norton for it's bloated, system killing performance, it seems in the past few years Norton has greatly improved their software. I figured for this price, I'd give it a shot since I'd be able to cover 3 PCs. So far, CPU utilization has been very low, it's run quietly in the background, and hasn't pestered me. I hope it's working, as I tend to surf smart and mostly avoid spyware / viruses because I don't click everything that pops up telling me I've won a prize....",
#   'overall': 4.0,
#   'summary': 'Norton pretty decent again',
#   'unixReviewTime': 1367625600,
#   'reviewTime': '05 4, 2013'},
#  {'reviewerID': 'A1FHO7JU6B3UTN',
#   'asin': 'B000H5SD5C',
#   'reviewerName': 'TB_SJCA',
#   'helpful': [2, 3],
#   'reviewText': 'This hose is awesome, it took a little while to relax due to the stiffness, but no binding or kinking whatsoever. Great hose for the money compared to brick and mortar retailers.',
#   'overall': 4.0,
#   'summary': 'Awesome hose for the money',
#   'unixReviewTime': 1328313600,
#   'reviewTime': '02 4, 2012'},
#  {'reviewerID': 'A1FHW2FZXHBLAZ',
#   'asin': '8492516119',
#   'reviewerName': 'Amazon Customer',
#   'helpful': [0, 0],
#   'reviewText': 'Este es el primer libro que leo de esta autora y debo decir que me parecio muy interesante. La historia no termina cuando los protagonistas se casan, sino que te deja ver que pasa despues del matrimonio. Una trama emocionante, triste y complicada pero con un bonito final. Recomendado.',
#   'overall': 5.0,
#   'summary': 'Mi primer libro de Quinn',
#   'unixReviewTime': 1265932800,
#   'reviewTime': '02 12, 2010'},
#  {'reviewerID': 'A1FIPVJGICSCC8',
#   'asin': 'B00ESXV54K',
#   'reviewerName': 'Chris',
#   'helpful': [0, 0],
#   'reviewText': "These are low cost Chinese whips. The first one I received had a couple of defects. The design includes a crimped-in washer to hold the retaining bearing in place. On the first unit, that washer protruded and kept the end from being inserted into the follow focus.  Also, the first unit had a fairly heavily abraded plastic sheathing. It would still have operated, if not for the other problem, but pretty sloppy. The packaging wasn't damaged at all, so someone placed it in a package with very apparent damage.Also, the shipping was really slow. I don't recall precisely, but perhaps a few weeks or more. I've ordered other products to be shipped from China that were received quite promptly.I sent the company detailed photos and they politely agreed to send a replacement. They didn't require the original unit to be returned. The replacement unit is fine. I'd probably have given it a rating of 4 stars, but for the poor quality control. Since the final unit works acceptably, it would be a value, but be prepared for trouble and you'd better not order from these guys if you're in a hurry.",
#   'overall': 3.0,
#   'summary': 'First Unit Defective, Replacement OK',
#   'unixReviewTime': 1386374400,
#   'reviewTime': '12 7, 2013'},
#  {'reviewerID': 'A1FNCR5CYJUN1T',
#   'asin': 'B000A8AXXQ',
#   'reviewerName': 'S. scott',
#   'helpful': [2, 2],
#   'reviewText': 'Got the CD after seeing her on Dr. Phil; Better than I could have expected.  A great CD for when you want to just kick back and enjoy country the way it was meant to be.  My favorite was "This Room."  Hope she\'s got another CD in the works; can\'t come out soon enough for me.',
#   'overall': 5.0,
#   'summary': 'How Sweet it is!',
#   'unixReviewTime': 1135728000,
#   'reviewTime': '12 28, 2005'},
#  {'reviewerID': 'A1FNH6S0SIFXGH',
#   'asin': 'B002610SB2',
#   'reviewerName': 'L. Schmitz "Busy Mom"',
#   'helpful': [2, 2],
#   'reviewText': 'Very comfortable shirt and washes up quite nicely. No ironing, thank goodness! I have several of this style in the different colors, and am usually asked where I found it! Really like this shirt!',
#   'overall': 5.0,
#   'summary': 'Love this Shirt!',
#   'unixReviewTime': 1347494400,
#   'reviewTime': '09 13, 2012'},
#  {'reviewerID': 'A1FNWN4VKW3LUN',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'Gnuguy',
#   'helpful': [0, 0],
#   'reviewText': 'It\'s well known now some dozen or so years since NYPD Blue graced our screens that it was a true "game changer." Even in this, now the era of "CSI" mania, the series still rings true proving that like fine wine it only gets better and better and better with age. Arguably the best "Cop" series of all-time...',
#   'overall': 5.0,
#   'summary': 'Forever a TV Classic',
#   'unixReviewTime': 1366329600,
#   'reviewTime': '04 19, 2013'},
#  {'reviewerID': 'A1FNX47I0IQ1WE',
#   'asin': 'B0046ZHQAW',
#   'reviewerName': 'amber',
#   'helpful': [0, 0],
#   'reviewText': 'Best iron ever! Highly recommended. Purchased on a whim, was recommended to me by product rep, so glad I took her advice. Not only my favorite iron ever, but my favorite tool ever. Softer, healthier cilicone grip. Fantastic heat controls. Great finisher at work, adds soft shine to clients hair. Great daily iron also, as thecilicone grips help to prevent crushing Kinks into the hair. Reduces the need to have your iron follow your comb.The girls at work are always saying &#34;can I borrow your iron? Its the best&#34; lolI LOVE THIS TOOL!',
#   'overall': 5.0,
#   'summary': 'best iron ever!',
#   'unixReviewTime': 1396483200,
#   'reviewTime': '04 3, 2014'},
#  {'reviewerID': 'A1FNY8B15Q6ETL',
#   'asin': 'B00BJW6AIE',
#   'reviewerName': 'Rhondajordan',
#   'helpful': [1, 1],
#   'reviewText': 'This was a good quick summer read, it had adventure, romance, drama, and even some sixpence. With WW 2 as a back drop...the story was interesting to learn of foreign war brides and what they gave up travelling to America.',
#   'overall': 4.0,
#   'summary': 'The war bride club',
#   'unixReviewTime': 1370736000,
#   'reviewTime': '06 9, 2013'},
#  {'reviewerID': 'A1FOOG5K5BWHTJ',
#   'asin': 'B004X1R3R0',
#   'reviewerName': 'Larry Nicholson',
#   'helpful': [0, 0],
#   'reviewText': 'This pulley is almost exactly like the one it replaced and works well.My old idler wheel was warped and worn out,throwing the drive belt if I mowed into tall grass (2 to 3&#34;,not baling hay tall).After 2 mowings no belt rejection of my expensive new belt and there is a remarkable reduction of noise from the mower deck.Well built product.',
#   'overall': 5.0,
#   'summary': 'Nice after-market clone',
#   'unixReviewTime': 1367020800,
#   'reviewTime': '04 27, 2013'},
#  {'reviewerID': 'A1FOPV6T30GW2K',
#   'asin': 'B008SCNCTI',
#   'reviewerName': 'Alice Green',
#   'helpful': [0, 0],
#   'reviewText': 'MY PRODUCTSFor the price, all the items exceeded my expections.  I am very pleased wioth them al;l and they are very handy and useful.',
#   'overall': 5.0,
#   'summary': 'MY PRODUCTS RECENTLY PURCHASED',
#   'unixReviewTime': 1384214400,
#   'reviewTime': '11 12, 2013'},
#  {'reviewerID': 'A1FOZGER2Y93U3',
#   'asin': 'B00CJ0TNPW',
#   'reviewerName': 'Salena McClain',
#   'helpful': [0, 0],
#   'reviewText': 'Love it this was for my teen age daugther. She showing all her friends they all love it also ty',
#   'overall': 5.0,
#   'summary': 'cover',
#   'unixReviewTime': 1379721600,
#   'reviewTime': '09 21, 2013'},
#  {'reviewerID': 'A1FPGKE7PZOBT4',
#   'asin': 'B001SBP9I8',
#   'reviewerName': 'Amber "Amber"',
#   'helpful': [1, 1],
#   'reviewText': 'Best bottle cap: easy one hand operation, high water flow, no leak, you can just click it close or lock it for extra safety.You do not have to embarassingly sucking on the cap just to get some water like other stainless steel bottles, wish they come in larger size.',
#   'overall': 5.0,
#   'summary': 'Best bottle cap',
#   'unixReviewTime': 1250640000,
#   'reviewTime': '08 19, 2009'},
#  {'reviewerID': 'A1FPQ1HHUZVGUM',
#   'asin': '1556659660',
#   'reviewerName': 'St. Corbinians\'s Bear "PAX"',
#   'helpful': [3, 3],
#   'reviewText': "First of all, this is probably not the best choice as a primary study Bible. (Check out Fireside's large print Librosario for that; it is what I would call &#34;comfortable,&#34; rather than &#34;large print.&#34;) There is a decent basic Catholic dictionary, but no maps at all. Since it is a NABRE it does come with the usual hit-or-miss notes, which are collected at the end of each book. It is too big to cart around, and too nice to risk dings. Despite its humongous size, the font seems on the small side, but I read two chapters of Isaiah today without problem. It is in an unusual three-column layout. Between that, the small font and large pages, the book of Ruth is only two pages! (Coincidentally, I found a 1961 Bible where we had RCIA class tonight, and it had the same layout.) The paper is real, thick, gilt edge book paper, so you don't have to worry about thin Bible pages. It has two ribbons, which is really nice. One for your couple study and one for your personal reading.It comes in a substantial slip cover with St. Peters stamped in gold. The cover is beautiful, thankfully not the Jesus portrait so often found on family Bibles. Just a striking red cross with a gold tile design near the edges of the cover. The spine is decorated, and tastefully incorporates the NABRE trademark. Although I believe it is bound with glue, there are ridges to suggest an heirloom. It looks and feels impressive, and Catholic.There are lovely color sections on The Mass (without one instance of the word &#34;sacrifice,&#34; unless I overlooked it); Parenting; Grief and The Vatican; as well as children's stories and activities for Christmas. There is the customary portrait of the reigning Bishop of Rome, and a list of all his predecessors. The various sections provide appropriate traditional and modern prayers, which I thought was nice. There is an excellent family record section, with places for eight kids. (This is a Catholic Bible, after all.) It goes back to your great -grandparents, and also has lines for things like military service, organizations (say, Benedictine oblates), and even papal audiences! It is so well done I'm inspired to fill it out, once I figure out how to write on slick paper without making a mess.Bibles like this are more likely to be owned than read, which is somewhat of a shame. I would guess most are purchased as gifts for parents or grandparents. (I received mine as a gift.) But it shall rest next to my favorite chair and be employed in daily lectio divina. It's just too nice to put away. There's just something about turning the pages of a large, beautiful book. Even better when it's Holy Scripture.So, in conclusion, it's a really big, very beautiful Catholic Family Bible suitable for devotional reading unless larger print is necessary. The extra material is more &#34;fluffy&#34; than scholarly, but of decent quality. Any Catholic adult should be pleased to receive it as a gift, and proud to display it in their home. The color sections are all useful in the family setting.St. Corbinian's Bear -- see you at my blog",
#   'overall': 5.0,
#   'summary': 'Very Nice Family Bible',
#   'unixReviewTime': 1392249600,
#   'reviewTime': '02 13, 2014'},
#  {'reviewerID': 'A1FQVKBOFHWKDX',
#   'asin': 'B001GIOW72',
#   'reviewerName': 'Neo Sharpe',
#   'helpful': [1, 1],
#   'reviewText': "I love this hand soap. It is really hard for me to find an anti-bacterial hand soap that is all natural and doesn't test on animals- this is ALL of those things! Plus, it smells GREAT! I buy these in bulk.",
#   'overall': 5.0,
#   'summary': 'Love This Stuff!',
#   'unixReviewTime': 1372809600,
#   'reviewTime': '07 3, 2013'},
#  {'reviewerID': 'A1FQW5VVYAIV75',
#   'asin': 'B002TK193G',
#   'reviewerName': 'Pattylouyse',
#   'helpful': [0, 1],
#   'reviewText': "We recently bought this for our 5 year old's birthday party. I was a bit nervous that it would be cheaply made & possibly break first time out of the box (especially due to some of the reviews). I will say - it had a noticeable small hole in the front that I could hear hissing when we first inflated it. It was easily mended with needle & thread. Since then we have used it multiple times with lots of young kids - with no leak (knock on wood). Our son loves it! Our 2 year old girl enjoys splashing around in the pool too & sitting under the shower.It is a little daunting to put away so I leave that to my husband. We hang it from a tree using a pulley system to let it dry (I'm not strong enough to do that alone). After it's dry we shove it back into the bag.*We also purchased this from Kohls on sale for closer to $200.",
#   'overall': 5.0,
#   'summary': 'Great for our 5 year old son',
#   'unixReviewTime': 1403395200,
#   'reviewTime': '06 22, 2014'},
#  {'reviewerID': 'A1FRK5WRI2SGKU',
#   'asin': 'B0001DU3SK',
#   'reviewerName': 'Brenda Davidson',
#   'helpful': [1, 1],
#   'reviewText': 'Everything seemed fine,at first (ie the kit contained the right instructions and thread for the cat) BUT the canvas in the kit was a HORSE not a cat!!! So the whole kit is useless. I am so disappointed as I really wanted the Cat (I own two lovely real Birman cats who look exactly like the tapestry!). Unfortunately I live outside USA so returning a $6 item is not practical. I shall re-order and hope for the best next time!!.',
#   'overall': 1.0,
#   'summary': 'Non-cuddly Cat.',
#   'unixReviewTime': 1386115200,
#   'reviewTime': '12 4, 2013'},
#  {'reviewerID': 'A1FSZXH6EQZQN0',
#   'asin': 'B00007I6FP',
#   'reviewerName': 'kelwms1967',
#   'helpful': [0, 0],
#   'reviewText': "NYPD Blue was groundbreaking television.  The show started much needed conversations on many topics.  It's a show that likely would not make it today due to the controversy.  If you are looking to be entertained and made to think, take a look at NYPD Blue!",
#   'overall': 5.0,
#   'summary': 'Groundbreaking TV',
#   'unixReviewTime': 1372896000,
#   'reviewTime': '07 4, 2013'},
#  {'reviewerID': 'A1FU7O908FJS27',
#   'asin': 'B00CJ0TNPW',
#   'reviewerName': 'Brandon',
#   'helpful': [3, 3],
#   'reviewText': "I don't know if it was just my item or the whole thing, but this might actually be a screen protector for the Lumia 520, which has a screen about a quarter of an inch shorter.",
#   'overall': 1.0,
#   'summary': 'Might not be the right item',
#   'unixReviewTime': 1369353600,
#   'reviewTime': '05 24, 2013'},
#  {'reviewerID': 'A1FUPDZL2AEM3K',
#   'asin': 'B00H46551W',
#   'reviewerName': 'playmesa',
#   'helpful': [0, 0],
#   'reviewText': 'I was hoping for so much more.  Uninstalled within 24 hours.  Not worth your time, but maybe the paid version is better.',
#   'overall': 2.0,
#   'summary': 'Uninstalled :(',
#   'unixReviewTime': 1400371200,
#   'reviewTime': '05 18, 2014'},
#  ...]

# %%
reviews = pd.DataFrame.from_records(raw_training)

# %%
reviews.head()
# Out:
#               reviewerID        asin              reviewerName helpful  \
# 0  A007549913T3THC2E44K5  B0046ZHQAW                     Marce  [3, 4]
# 1  A03666331WS5WUZMM0AUD  B00007M0CP  Susanne Gonzalez Delgado  [3, 3]
# 2  A03898972RKS9HXS4H1F3  B002610SB2       Nancy Denise Graves  [4, 5]
# 3   A04051149NH0IDZZ4FH7  B002610SB2                    Donnie  [4, 4]
# 4  A06263011FDVMGFVAALWO  B00007M0CP               Hannah Moss  [0, 0]
#
#                                           reviewText  overall  \
# 0  is a very good iron, your hair look beautiful ...      5.0
# 1  Good quality for this Price. The curls gets qu...      5.0
# 2  The shirt fits perfectly--true to size.  It is...      5.0
# 3  Wife hates hot days, well we live in florida.....      5.0
# 4  So much faster for me than using a curling iro...      5.0
#
#                                              summary  unixReviewTime  \
# 0                                    Really good one      1366329600
# 1  Conair Xtreme Instant Heat Multisized Hot Roll...      1378080000
# 2             It was exactly what I was looking for!      1358726400
# 3                            Nice shirt for the wife      1394755200
# 4                                       I love them!      1365984000
#
#     reviewTime
# 0  04 19, 2013
# 1   09 2, 2013
# 2  01 21, 2013
# 3  03 14, 2014
# 4  04 15, 2013

# %%
reviews.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime'],
#       dtype='object')

# %%
reviews.drop(['reviewerID', 'asin', 'reviewerName', 'unixReviewTime', 'reviewTime'], axis=1, inplace=True)

# %%
reviews.reviewerID.value_counts()
# Out:
# A14OJS0VWMOSWO    7
# A15C3UT9FCQYTN    2
# A13QTZ8CIMHHG4    2
# A1W8EAPN3ZTI9     1
# A1W670KK0YNM74    1
#                  ..
# A1FUTP0MAGGN8V    1
# A1FV7W4SZD9BVO    1
# A1FV82A6PT1LEL    1
# A1FV9CE5LZMKHL    1
# A2E64WQS9WFEM9    1
# Name: reviewerID, Length: 2965, dtype: int64

# %%
reviews.head()
# Out:
#               reviewerID        asin              reviewerName helpful  \
# 0  A007549913T3THC2E44K5  B0046ZHQAW                     Marce  [3, 4]
# 1  A03666331WS5WUZMM0AUD  B00007M0CP  Susanne Gonzalez Delgado  [3, 3]
# 2  A03898972RKS9HXS4H1F3  B002610SB2       Nancy Denise Graves  [4, 5]
# 3   A04051149NH0IDZZ4FH7  B002610SB2                    Donnie  [4, 4]
# 4  A06263011FDVMGFVAALWO  B00007M0CP               Hannah Moss  [0, 0]
#
#                                           reviewText  overall  \
# 0  is a very good iron, your hair look beautiful ...      5.0
# 1  Good quality for this Price. The curls gets qu...      5.0
# 2  The shirt fits perfectly--true to size.  It is...      5.0
# 3  Wife hates hot days, well we live in florida.....      5.0
# 4  So much faster for me than using a curling iro...      5.0
#
#                                              summary  unixReviewTime  \
# 0                                    Really good one      1366329600
# 1  Conair Xtreme Instant Heat Multisized Hot Roll...      1378080000
# 2             It was exactly what I was looking for!      1358726400
# 3                            Nice shirt for the wife      1394755200
# 4                                       I love them!      1365984000
#
#     reviewTime
# 0  04 19, 2013
# 1   09 2, 2013
# 2  01 21, 2013
# 3  03 14, 2014
# 4  04 15, 2013

# %%
reviews.shape
# Out:
# (2973, 9)

# %%
reviews.describe()
# Out:
#            overall  unixReviewTime
# count  2973.000000    2.973000e+03
# mean      4.153380    1.331244e+09
# std       1.237598    9.093277e+07
# min       1.000000    8.864640e+08
# 25%       4.000000    1.310256e+09
# 50%       5.000000    1.365984e+09
# 75%       5.000000    1.389485e+09
# max       5.000000    1.405987e+09

# %%
reviews.overall.value_counts()
# Out:
# 5.0    1712
# 4.0     604
# 3.0     286
# 1.0     228
# 2.0     143
# Name: overall, dtype: int64

# %% [markdown]
# What fields should be our independent (X) variables?
# Convert data frame:  include only desired X variables, and code the y variable

# %%
reviews = reviews[reviews.overall != 3]

# %%
raw_training = np.delete(raw_training, list(map(lambda j: j['overall'] == 3.0, raw_training)))

# %%
reviews.shape
# Out:
# (2687, 9)

# %%
len(raw_training)
# Out:
# 2687

# %%
reviews.overall.value_counts()
# Out:
# 5.0    1712
# 4.0     604
# 1.0     228
# 2.0     143
# Name: overall, dtype: int64

# %%
y = list(map(lambda s: 0 if s < 3 else 1, reviews.overall))

# %%
reviews.drop(['overall'], axis=1, inplace=True)
# Out:
# C:\Users\hanks\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
reviews.shape
# Out:
# (2687, 8)

# %%
reviews.head()
# Out:
#               reviewerID        asin              reviewerName helpful  \
# 0  A007549913T3THC2E44K5  B0046ZHQAW                     Marce  [3, 4]
# 1  A03666331WS5WUZMM0AUD  B00007M0CP  Susanne Gonzalez Delgado  [3, 3]
# 2  A03898972RKS9HXS4H1F3  B002610SB2       Nancy Denise Graves  [4, 5]
# 3   A04051149NH0IDZZ4FH7  B002610SB2                    Donnie  [4, 4]
# 4  A06263011FDVMGFVAALWO  B00007M0CP               Hannah Moss  [0, 0]
#
#                                           reviewText  \
# 0  is a very good iron, your hair look beautiful ...
# 1  Good quality for this Price. The curls gets qu...
# 2  The shirt fits perfectly--true to size.  It is...
# 3  Wife hates hot days, well we live in florida.....
# 4  So much faster for me than using a curling iro...
#
#                                              summary  unixReviewTime  \
# 0                                    Really good one      1366329600
# 1  Conair Xtreme Instant Heat Multisized Hot Roll...      1378080000
# 2             It was exactly what I was looking for!      1358726400
# 3                            Nice shirt for the wife      1394755200
# 4                                       I love them!      1365984000
#
#     reviewTime
# 0  04 19, 2013
# 1   09 2, 2013
# 2  01 21, 2013
# 3  03 14, 2014
# 4  04 15, 2013

# %%
reviews['text'] = reviews.reviewText + reviews.summary
# Out:
# C:\Users\hanks\AppData\Local\Temp/ipykernel_12484/2652711557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['text'] = reviews.reviewText + reviews.summary

# %%
reviews.head()
# Out:
#               reviewerID        asin              reviewerName helpful  \
# 0  A007549913T3THC2E44K5  B0046ZHQAW                     Marce  [3, 4]
# 1  A03666331WS5WUZMM0AUD  B00007M0CP  Susanne Gonzalez Delgado  [3, 3]
# 2  A03898972RKS9HXS4H1F3  B002610SB2       Nancy Denise Graves  [4, 5]
# 3   A04051149NH0IDZZ4FH7  B002610SB2                    Donnie  [4, 4]
# 4  A06263011FDVMGFVAALWO  B00007M0CP               Hannah Moss  [0, 0]
#
#                                           reviewText  \
# 0  is a very good iron, your hair look beautiful ...
# 1  Good quality for this Price. The curls gets qu...
# 2  The shirt fits perfectly--true to size.  It is...
# 3  Wife hates hot days, well we live in florida.....
# 4  So much faster for me than using a curling iro...
#
#                                              summary  unixReviewTime  \
# 0                                    Really good one      1366329600
# 1  Conair Xtreme Instant Heat Multisized Hot Roll...      1378080000
# 2             It was exactly what I was looking for!      1358726400
# 3                            Nice shirt for the wife      1394755200
# 4                                       I love them!      1365984000
#
#     reviewTime                                               text
# 0  04 19, 2013  is a very good iron, your hair look beautiful ...
# 1   09 2, 2013  Good quality for this Price. The curls gets qu...
# 2  01 21, 2013  The shirt fits perfectly--true to size.  It is...
# 3  03 14, 2014  Wife hates hot days, well we live in florida.....
# 4  04 15, 2013  So much faster for me than using a curling iro...

# %%
print(reviews.shape)
print(len(y))
# Out:
# (2687, 9)
# 2687

# %% [markdown]
# Now we have a text field as our X, and we have to convert it to a real input vector.
# First look at CountVectorizer:  https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %%
from sklearn.feature_extraction.text import CountVectorizer
#v = CountVectorizer(min_df=2, max_df=.75)
#v = CountVectorizer(max_df=.25)
v = CountVectorizer()
X = v.fit_transform(reviews.text)

# %% [markdown]
# Side step:  look at excluding very rare terms (min_df) and very common terms (max_df)

# %%
len(v.vocabulary_.keys())
# Out:
# 15368

# %%
v.vocabulary_
# Out:
# {'is': 7356,
#  'very': 14699,
#  'good': 6046,
#  'iron': 7341,
#  'your': 15320,
#  'hair': 6284,
#  'look': 8151,
#  'beautiful': 1511,
#  'and': 870,
#  'in': 6971,
#  'just': 7558,
#  'one': 9457,
#  'pass': 9807,
#  'does': 4241,
#  'not': 9253,
#  'hurt': 6808,
#  'the': 13730,
#  'it': 7378,
#  'all': 747,
#  'can': 2236,
#  'sayreally': 11831,
#  'quality': 10775,
#  'for': 5572,
#  'this': 13793,
#  'price': 10471,
#  'curls': 3534,
#  'gets': 5923,
#  'quite': 10816,
#  'tight': 13872,
#  'if': 6871,
#  'you': 15311,
#  'have': 6413,
#  'eacute': 4470,
#  'dium': 4198,
#  'long': 8141,
#  'now': 9288,
#  'longer': 8142,
#  'results': 11395,
#  'looks': 8156,
#  'better': 1627,
#  'as': 1110,
#  'more': 8864,
#  'natural': 9055,
#  'only': 9472,
#  'thing': 13777,
#  'dislike': 4152,
#  'that': 13722,
#  'my': 8989,
#  'fingers': 5379,
#  'get': 5919,
#  'constantly': 3140,
#  'burned': 2125,
#  'guess': 6226,
#  'am': 802,
#  'at': 1169,
#  'but': 2148,
#  'would': 15222,
#  'be': 1481,
#  'gread': 6145,
#  'came': 2216,
#  'with': 15136,
#  'special': 12765,
#  'glove': 6010,
#  'to': 13922,
#  'avoid': 1272,
#  'top': 13974,
#  'product': 10538,
#  'definitely': 3762,
#  'recommend': 11039,
#  'conair': 3013,
#  'xtreme': 15274,
#  'instant': 7177,
#  'heat': 6484,
#  'multisized': 8951,
#  'hot': 6729,
#  'rollers': 11601,
#  'pink': 10097,
#  'shirt': 12247,
#  'fits': 5408,
#  'perfectly': 9939,
#  'true': 14192,
#  'size': 12440,
#  'easy': 4507,
#  'care': 2306,
#  'never': 9154,
#  'needs': 9110,
#  'ironing': 7345,
#  'will': 15088,
#  'buying': 2162,
#  'near': 9082,
#  'future': 5796,
#  'great': 6149,
#  'buy': 2158,
#  'was': 14896,
#  'exactly': 4957,
#  'what': 15008,
#  'looking': 8155,
#  'wife': 15076,
#  'hates': 6405,
#  'days': 3660,
#  'well': 14988,
#  'we': 14941,
#  'live': 8077,
#  'florida': 5499,
#  'keeps': 7596,
#  'her': 6542,
#  'nagging': 9013,
#  'down': 4299,
#  'minimum': 8714,
#  'she': 12199,
#  'dosn': 4287,
#  'complain': 2963,
#  'about': 401,
#  'being': 1567,
#  'sweaty': 13420,
#  'nice': 9170,
#  'so': 12610,
#  'much': 8929,
#  'faster': 5236,
#  'me': 8519,
#  'than': 13712,
#  'using': 14588,
#  'curling': 3533,
#  'curl': 3528,
#  'everyday': 4931,
#  'love': 8196,
#  'these': 13766,
#  'they': 13769,
#  're': 10926,
#  'worth': 15218,
#  'them': 13738,
#  'when': 15017,
#  'dogs': 4247,
#  'gobble': 6025,
#  'treats': 14125,
#  '60': 298,
#  'then': 13747,
#  'know': 7691,
#  'are': 1053,
#  'taste': 13561,
#  'priced': 10473,
#  'right': 11506,
#  'too': 13962,
#  'give': 5963,
#  'paws': 9866,
#  'up': 14532,
#  'like': 8003,
#  'police': 10237,
#  'drama': 4327,
#  'shows': 12299,
#  'old': 9439,
#  'school': 11874,
#  '90': 349,
#  'show': 12293,
#  'writer': 15244,
#  'many': 8388,
#  'actors': 526,
#  'real': 10954,
#  'life': 7978,
#  'events': 4920,
#  'outstanding': 9623,
#  'series': 12093,
#  'cd': 2401,
#  'bargain': 1417,
#  'breath': 1961,
#  'of': 9403,
#  'fresh': 5699,
#  'air': 703,
#  'few': 5317,
#  'songs': 12680,
#  'were': 14996,
#  'on': 9453,
#  '1982': 134,
#  'sampler': 11768,
#  'lp': 8223,
#  'from': 5729,
#  'record': 11049,
#  'company': 2935,
#  'irs': 7355,
#  'total': 13998,
#  '22': 177,
#  'tracks': 14034,
#  'an': 852,
#  'extravaganza': 5118,
#  'early': 4482,
#  'by': 2169,
#  'new': 9156,
#  'wave': 14931,
#  'bands': 1401,
#  'rather': 10897,
#  'list': 8054,
#  'groups': 6212,
#  'enough': 4759,
#  'ensure': 4767,
#  'any': 946,
#  '80s': 329,
#  'post': 10316,
#  'punk': 10709,
#  'fan': 5201,
#  'go': 6021,
#  'gos': 6061,
#  'wayne': 14937,
#  'county': 3339,
#  'electric': 4600,
#  'chairs': 2457,
#  'wazmo': 14940,
#  'nariz': 9032,
#  'root': 11623,
#  'boy': 1913,
#  'slim': 12503,
#  'skafish': 12444,
#  'john': 7501,
#  'cale': 2195,
#  'oingo': 9432,
#  'boingo': 1817,
#  'lad': 7741,
#  'klark': 7672,
#  'kent': 7610,
#  'stewart': 13023,
#  'copeland': 3264,
#  'before': 1540,
#  'he': 6436,
#  'founded': 5633,
#  'buzzcocks': 2165,
#  'english': 4738,
#  'beat': 1500,
#  'cramps': 3382,
#  'magazine': 8290,
#  'wall': 14848,
#  'voodoo': 14803,
#  'mexican': 8644,
#  'radio': 10844,
#  'alarm': 723,
#  'dr': 4319,
#  'medics': 8554,
#  'lords': 8170,
#  'church': 2632,
#  'timbuk': 13885,
#  'fine': 5371,
#  'young': 15315,
#  'cannibals': 2256,
#  'caterwaul': 2378,
#  'concrete': 3041,
#  'blonde': 1756,
#  'see': 12015,
#  'told': 13943,
#  'inclusive': 6995,
#  'period': 9954,
#  'faves': 5254,
#  'some': 12663,
#  'familiar': 5194,
#  'other': 9574,
#  'want': 14866,
#  'intro': 7281,
#  'late': 7801,
#  '70s': 316,
#  'scene': 11857,
#  'enjoy': 4746,
#  'note': 9258,
#  'had': 6279,
#  'fave': 5253,
#  'teaser': 13597,
#  'shubargain': 12309,
#  'mostly': 8873,
#  'rare': 10888,
#  'performances': 9944,
#  'vibrant': 14711,
#  'color': 2852,
#  'soft': 12628,
#  'material': 8473,
#  'something': 12669,
#  'make': 8326,
#  'stand': 12923,
#  'out': 9584,
#  'crowd': 3466,
#  'through': 13834,
#  'bright': 1996,
#  'there': 13758,
#  'products': 10544,
#  'limited': 8019,
#  'their': 13736,
#  'applications': 1000,
#  'bougth': 1890,
#  'because': 1518,
#  'flashligth': 5439,
#  'used': 14572,
#  'couldn': 3326,
#  'where': 15019,
#  'broken': 2025,
#  'ended': 4710,
#  '4a': 262,
#  'batteries': 1464,
#  'don': 4263,
#  'need': 9102,
#  'dog': 4245,
#  'leave': 7884,
#  'everyone': 4934,
#  'alone': 772,
#  '20': 151,
#  'minutes': 8727,
#  'kong': 7704,
#  'treat': 14120,
#  'prepared': 10428,
#  'advance': 603,
#  'cow': 3361,
#  'bone': 1829,
#  'doesn': 4242,
#  'even': 4912,
#  'last': 7793,
#  'wrong': 15251,
#  'side': 12324,
#  'those': 13803,
#  'teeth': 13622,
#  'here': 6543,
#  'how': 6746,
#  'put': 10740,
#  'akong': 720,
#  'stuff': 13182,
#  'snacks': 12581,
#  'liver': 8080,
#  '11': 31,
#  'ounce': 9579,
#  'largein': 7786,
#  'toy': 14022,
#  'paste': 9824,
#  'around': 1079,
#  'sometimes': 12672,
#  'fill': 5346,
#  'way': 14936,
#  'also': 780,
#  'leftover': 7899,
#  'meat': 8540,
#  'or': 9524,
#  'fish': 5401,
#  'short': 12270,
#  'order': 9537,
#  'freezer': 5688,
#  'against': 664,
#  'day': 3655,
#  'driving': 4385,
#  'crazy': 3397,
#  'takes': 13507,
#  'freeze': 5687,
#  'same': 11763,
#  'distraction': 4191,
#  'shoes': 12256,
#  've': 14653,
#  'gotten': 6071,
#  'ton': 13953,
#  'compliments': 2983,
#  'purchased': 10718,
#  'wear': 14949,
#  'cheerleading': 2539,
#  'aerobic': 628,
#  'dance': 3606,
#  'class': 2680,
#  'cheerobix': 2540,
#  'work': 15185,
#  'really': 10966,
#  'lot': 8179,
#  'support': 13346,
#  'lacking': 7738,
#  'worn': 15208,
#  'times': 13895,
#  'imagine': 6913,
#  'once': 9455,
#  'won': 15163,
#  'bother': 1880,
#  'ankle': 903,
#  'bit': 1698,
#  'rubbing': 11673,
#  'deter': 3936,
#  'wearing': 14951,
#  '10': 19,
#  'wide': 15069,
#  'feet': 5288,
#  'thinking': 13782,
#  'two': 14298,
#  'thumbs': 13850,
#  'cute': 3561,
#  'do': 4220,
#  'job': 7495,
#  'rah': 10850,
#  'book': 1841,
#  'fills': 5351,
#  'missing': 8757,
#  'pages': 9704,
#  'street': 13116,
#  'history': 6625,
#  'documents': 4236,
#  'african': 649,
#  'americans': 830,
#  'overcame': 9634,
#  'racism': 10834,
#  'barriers': 1426,
#  'become': 1521,
#  'successful': 13258,
#  'financial': 5366,
#  'securities': 12011,
#  'industry': 7051,
#  'should': 12282,
#  'part': 9789,
#  'every': 4928,
#  'business': 2142,
#  'curriculum': 3539,
#  'first': 5399,
#  'best': 1619,
#  'its': 7397,
#  'kind': 7643,
#  'no': 9212,
#  'stars': 12944,
#  'screen': 11926,
#  'comes': 2885,
#  'tap': 13543,
#  'caption': 2283,
#  'changes': 2475,
#  'huh': 6766,
#  'been': 1534,
#  'coleman': 2830,
#  'stoves': 13078,
#  'until': 14520,
#  'previous': 10469,
#  'reviewer': 11441,
#  'posted': 10319,
#  'shoddy': 12254,
#  'construction': 3150,
#  'ultra': 14330,
#  'low': 8212,
#  'sheet': 12207,
#  'metal': 8629,
#  'combine': 2870,
#  'create': 3405,
#  'ready': 10951,
#  'rid': 11492,
#  'edges': 4536,
#  'sharp': 12188,
#  'latch': 7799,
#  'due': 4429,
#  'engineering': 4734,
#  'manufacturing': 8387,
#  'issue': 7373,
#  'bottom': 1887,
#  'green': 6159,
#  'piece': 10080,
#  'fit': 5406,
#  'properly': 10612,
#  'into': 7276,
#  'silver': 12363,
#  'lip': 8045,
#  'currently': 3538,
#  'replacement': 11286,
#  'stove': 13076,
#  'horribly': 6710,
#  'made': 8281,
#  'said': 11738,
#  'cook': 3242,
#  'pretty': 10459,
#  'without': 15144,
#  'crushed': 3481,
#  'car': 2291,
#  'ride': 11495,
#  'camp': 2225,
#  'site': 12426,
#  'point': 10222,
#  'cruddy': 3474,
#  'outweighs': 9626,
#  'functionality': 5770,
#  'spend': 12792,
#  '15': 59,
#  'min': 8692,
#  'each': 4468,
#  'app': 974,
#  'daughter': 3642,
#  '38': 233,
#  'having': 6416,
#  'fun': 5767,
#  'hope': 6696,
#  'bought': 1889,
#  'inside': 7145,
#  'kept': 7612,
#  'occupied': 9385,
#  'hours': 6737,
#  'year': 15288,
#  'grandmother': 6118,
#  'has': 6391,
#  'searching': 11978,
#  'high': 6576,
#  'fashion': 5230,
#  'cotton': 3318,
#  'bra': 1918,
#  'elastic': 4592,
#  'bras': 1942,
#  'chap': 2482,
#  'skin': 12459,
#  'directly': 4060,
#  'touching': 14009,
#  'louisiana': 8193,
#  'california': 2200,
#  'loves': 8208,
#  'sisters': 12424,
#  'asking': 1120,
#  'place': 10130,
#  'orders': 9540,
#  'tested': 13688,
#  'doubts': 4294,
#  'exceed': 4968,
#  'expectations': 5033,
#  'since': 12396,
#  'seen': 12026,
#  'people': 9920,
#  'exquisite': 5100,
#  'thanks': 13716,
#  'amazon': 815,
#  'yes': 15298,
#  'lookin': 8154,
#  'sexy': 12150,
#  'may': 8497,
#  'small': 12536,
#  'protect': 10630,
#  'underneath': 14390,
#  'front': 5732,
#  'seats': 11987,
#  'expensive': 5041,
#  'custom': 3551,
#  'ask': 1118,
#  'both': 1879,
#  'back': 1326,
#  'together': 13935,
#  'must': 8982,
#  'admit': 583,
#  'albums': 730,
#  'download': 4303,
#  '18': 78,
#  '06': 6,
#  'passion': 9814,
#  'play': 10171,
#  'tull': 14240,
#  'album': 729,
#  'keep': 7593,
#  'complete': 2971,
#  'collection': 2840,
#  'fact': 5156,
#  'shuffled': 12312,
#  'retirement': 11412,
#  'projects': 10582,
#  'digitize': 4027,
#  'tapes': 13547,
#  'less': 7935,
#  'music': 8971,
#  'recording': 11051,
#  'purists': 10728,
#  'prefer': 10405,
#  'vinyl': 14742,
#  'which': 15027,
#  'moments': 8824,
#  'notice': 9264,
#  'while': 15030,
#  'star': 12934,
#  'nothing': 9263,
#  'seeing': 12018,
#  'jt': 7526,
#  'ian': 6832,
#  'concert': 3029,
#  'sure': 13360,
#  'check': 2529,
#  'performing': 9948,
#  'taab': 13476,
#  'taab2': 13477,
#  'sf': 12151,
#  'july': 7544,
#  'dawgjethro': 3651,
#  'set': 12116,
#  'favorite': 5257,
#  'television': 13624,
#  'time': 13886,
#  'second': 11993,
#  'wire': 15118,
#  'although': 791,
#  'yorker': 15308,
#  'related': 11166,
#  'dealt': 3680,
#  'denis': 3829,
#  'franz': 5668,
#  'character': 2485,
#  'andy': 884,
#  'miss': 8752,
#  'off': 9405,
#  'characters': 2489,
#  'week': 14968,
#  'whenever': 15018,
#  'reason': 10975,
#  'got': 6067,
#  'prime': 10486,
#  'needed': 9103,
#  'norton': 9243,
#  '360': 230,
#  'ordered': 9538,
#  'however': 6748,
#  'went': 14994,
#  'install': 7169,
#  'message': 8623,
#  'replace': 11283,
#  'newer': 9159,
#  'version': 14696,
#  'already': 778,
#  'computer': 3006,
#  'windows': 15101,
#  'hp': 6751,
#  'trial': 14141,
#  'stuck': 13171,
#  'spent': 12796,
#  'loaded': 8093,
#  'cannot': 2257,
#  'cancel': 2239,
#  'return': 11420,
#  'downloaded': 4304,
#  'apparently': 980,
#  'current': 3537,
#  'drawing': 4342,
#  'im': 6901,
#  'wasnt': 14906,
#  'draw': 4335,
#  'boss': 1875,
#  'wish': 15128,
#  'unlocked': 14468,
#  'witout': 15150,
#  'pay': 9867,
#  'themcool': 13740,
#  'though': 13804,
#  'saw': 11822,
#  'episodes': 4812,
#  'years': 15290,
#  'ago': 679,
#  'seems': 12025,
#  'nostalgia': 9251,
#  'especially': 4862,
#  'via': 14707,
#  'tv': 14270,
#  'memories': 8588,
#  'regardless': 11118,
#  'politics': 10251,
#  'faith': 5179,
#  'system': 13469,
#  'read': 10937,
#  'divisive': 4213,
#  'learn': 7874,
#  'civil': 2664,
#  'dialogs': 3981,
#  'midst': 8667,
#  'competing': 2956,
#  'views': 14730,
#  'tear': 13592,
#  'another': 925,
#  'apart': 958,
#  'slaughter': 12477,
#  'et': 4887,
#  'al': 721,
#  'call': 2202,
#  'sit': 12425,
#  'table': 13479,
#  'discuss': 4133,
#  'implications': 6946,
#  'policy': 10243,
#  'political': 10248,
#  'season': 11981,
#  'started': 12948,
#  'hobby': 6638,
#  'career': 2308,
#  'designer': 3896,
#  'struggling': 13167,
#  'getting': 5924,
#  'organized': 9549,
#  'knowing': 7693,
#  'start': 12947,
#  'includes': 6992,
#  'essentials': 4873,
#  'basics': 1445,
#  'design': 3894,
#  'checked': 2530,
#  'library': 7963,
#  'after': 651,
#  'reading': 10947,
#  'cover': 3354,
#  'decided': 3708,
#  'own': 9670,
#  'copy': 3273,
#  'highly': 6583,
#  'designers': 3897,
#  'picture': 10077,
#  'adjusted': 570,
#  'sound': 12713,
#  'folding': 5544,
#  'makes': 8330,
#  'compact': 2931,
#  'antenna': 930,
#  'strap': 13096,
#  'works': 15198,
#  'position': 10300,
#  'yourself': 15322,
#  'reception': 11006,
#  'calendar': 2197,
#  'books': 1846,
#  'illustrations': 6899,
#  'wonderful': 15166,
#  'daily': 3588,
#  'reminder': 11230,
#  'fabulous': 5140,
#  'drawings': 4343,
#  'chef': 2545,
#  'home': 6664,
#  'kids': 7633,
#  'who': 15055,
#  'growing': 6214,
#  'cooking': 3246,
#  'kitchen': 7666,
#  'bait': 1363,
#  'bar': 1410,
#  'multiple': 8950,
#  'rats': 10905,
#  'our': 9581,
#  'compost': 2994,
#  'pile': 10086,
#  'within': 15140,
#  'gone': 6044,
#  'found': 5630,
#  'dead': 3668,
#  '34': 223,
#  'controversial': 3216,
#  'aired': 706,
#  'little': 8075,
#  'nudity': 9307,
#  'episode': 4811,
#  'gritty': 6192,
#  'moving': 8914,
#  'story': 13069,
#  'experience': 5043,
#  'private': 10508,
#  'lives': 8081,
#  'broke': 2024,
#  'ice': 6836,
#  'dennis': 3830,
#  'whole': 15057,
#  'cop': 3262,
#  'nypd': 9337,
#  'blue': 1774,
#  'expert': 5053,
#  'creating': 3408,
#  'designs': 3900,
#  'guide': 6233,
#  'feel': 5282,
#  'things': 13778,
#  'useful': 14574,
#  'listening': 8060,
#  'zia': 15351,
#  'mohiuddin': 8807,
#  'dagar': 3586,
#  'rudra': 11678,
#  'veena': 14658,
#  'watching': 14919,
#  'night': 9186,
#  'contemplate': 3171,
#  'ways': 14938,
#  'move': 8905,
#  'relation': 11169,
#  'understand': 14395,
#  'imaginatively': 6912,
#  'creates': 3407,
#  'precise': 10387,
#  'relationships': 11173,
#  'between': 1631,
#  'tones': 13956,
#  'plays': 10182,
#  'heavenly': 6491,
#  'spheres': 12798,
#  'called': 2204,
#  'henry': 6541,
#  'probably': 10517,
#  'far': 5218,
#  'accurate': 471,
#  'portrayal': 10293,
#  'ireland': 7338,
#  'british': 2013,
#  'rule': 11684,
#  'realise': 10955,
#  'activities': 522,
#  'members': 8583,
#  'michael': 8650,
#  'collins': 2846,
#  'quot': 10817,
#  'squad': 12882,
#  'performed': 9945,
#  'smart': 12542,
#  'novel': 9278,
#  'periphery': 9957,
#  'possibly': 10315,
#  'most': 8872,
#  'effective': 4561,
#  'counter': 3330,
#  'intellegence': 7205,
#  'agency': 669,
#  'world': 15202,
#  'roddy': 11585,
#  'doyle': 4315,
#  'excellent': 4974,
#  'captures': 2289,
#  'anything': 951,
#  'hitherto': 6627,
#  'subject': 13217,
#  'feeling': 5284,
#  'dubliners': 4426,
#  'towards': 14015,
#  'easter': 4505,
#  'rising': 11535,
#  'executions': 4997,
#  'attitude': 1207,
#  'beyond': 1637,
#  'pale': 9723,
#  'controlled': 3209,
#  'region': 11124,
#  'dublin': 4424,
#  'phrase': 10056,
#  'jackeens': 7410,
#  'delay': 3782,
#  'leaving': 7886,
#  'believe': 1575,
#  'surprising': 13378,
#  'seem': 12021,
#  'think': 13780,
#  'loyalty': 8222,
#  'similar': 12367,
#  'his': 6615,
#  'feelings': 5285,
#  'james': 7430,
#  'connolly': 3109,
#  'debt': 3695,
#  'honour': 6684,
#  'him': 6599,
#  'abandoning': 382,
#  'unresolved': 14498,
#  'betrayal': 1625,
#  'death': 3686,
#  'free': 5677,
#  'country': 3337,
#  'attributes': 1218,
#  'visible': 14758,
#  'major': 8324,
#  'influence': 7080,
#  'actions': 512,
#  'various': 14645,
#  'loyalties': 8221,
#  'strong': 13155,
#  'force': 5573,
#  'wasn': 14905,
#  'author': 1244,
#  'preferring': 10410,
#  'film': 5352,
#  'versions': 14697,
#  'barrytown': 1431,
#  'trilogy': 14160,
#  'await': 1275,
#  'anticipation': 941,
#  'remaining': 11210,
#  'latest': 7806,
#  'finest': 5375,
#  'hour': 6736,
#  'charlie': 2501,
#  'sheen': 12205,
#  'bowling': 1906,
#  'decent': 3705,
#  'problems': 10519,
#  'seasons': 11984,
#  'groundbreaking': 6204,
#  'watch': 14912,
#  'again': 660,
#  'appearances': 985,
#  'number': 9311,
#  'faces': 5145,
#  'classic': 2684,
#  'didn': 3998,
#  'smits': 12560,
#  'joined': 7506,
#  'loved': 8197,
#  'chance': 2470,
#  'beginning': 1554,
#  'planning': 10148,
#  'entire': 4789,
#  'excited': 4985,
#  'grow': 6213,
#  'compressed': 3000,
#  'frame': 5649,
#  'prim': 10483,
#  'shouldi': 12286,
#  'uninterrupted': 14443,
#  'almost': 771,
#  'forward': 5623,
#  'retired': 11411,
#  'robert': 11566,
#  'hall': 6307,
#  'us': 14561,
#  'basic': 1443,
#  'concepts': 3023,
#  'protecting': 10633,
#  'individuals': 7042,
#  'pitfalls': 10121,
#  'society': 12621,
#  'commonsense': 2922,
#  'devoid': 3961,
#  'mr': 8923,
#  'perspective': 9990,
#  'broad': 2016,
#  'insight': 7147,
#  'welcomed': 14984,
#  'refreshing': 11103,
#  'change': 2472,
#  'over': 9628,
#  'typical': 14307,
#  'main': 8313,
#  'stream': 13108,
#  'self': 12038,
#  'help': 6526,
#  'guides': 6236,
#  '12': 38,
#  'step': 12998,
#  'programs': 10569,
#  'focus': 5531,
#  'personal': 9982,
#  'safety': 11735,
#  'reliance': 11190,
#  'actual': 530,
#  'prevention': 10465,
#  'offers': 9413,
#  'simple': 12380,
#  'solutions': 12658,
#  'harm': 6374,
#  'adding': 551,
#  'humor': 6787,
#  'lessons': 7938,
#  'former': 5608,
#  'state': 12959,
#  'senator': 12048,
#  'veteran': 14701,
#  'fathers': 5243,
#  'family': 5197,
#  'supply': 13344,
#  'plan': 10141,
#  'safer': 11734,
#  'track': 14030,
#  'prophecy': 10614,
#  'did': 3996,
#  'expand': 5024,
#  'understanding': 14398,
#  'living': 8083,
#  'writing': 15247,
#  'informative': 7088,
#  'interested': 7229,
#  'writings': 15248,
#  'man': 8342,
#  'listen': 8056,
#  'song': 12678,
#  'such': 13263,
#  'prevalent': 10461,
#  'viral': 14750,
#  'pray': 10373,
#  'hear': 6469,
#  'beatrice': 1505,
#  'months': 8852,
#  'prepare': 10427,
#  'child': 2569,
#  'potentially': 10330,
#  'daunting': 3646,
#  'task': 13558,
#  'babysitting': 1321,
#  'grandpa': 6120,
#  'cracks': 3375,
#  'educational': 4551,
#  'win': 15096,
#  'winfor': 15107,
#  'granddaughter': 6109,
#  'popcorn': 10272,
#  'seasoning': 11983,
#  'salt': 11753,
#  'tastes': 13566,
#  'white': 15047,
#  'cheddar': 2533,
#  'finally': 5364,
#  'cheese': 2542,
#  'name': 9020,
#  'dry': 4408,
#  'kwikit': 7724,
#  'wonderfully': 15168,
#  'quick': 10797,
#  'drying': 4411,
#  'coat': 2793,
#  'done': 4266,
#  'painting': 9713,
#  'nails': 9016,
#  'nail': 9014,
#  'thin': 13776,
#  'oily': 9431,
#  'worry': 15212,
#  ...}

# %%
v.stop_words_
# Out:
# {'and',
#  'are',
#  'as',
#  'but',
#  'for',
#  'great',
#  'have',
#  'in',
#  'is',
#  'it',
#  'my',
#  'not',
#  'of',
#  'on',
#  'so',
#  'that',
#  'the',
#  'this',
#  'to',
#  'was',
#  'with',
#  'you'}

# %%
print(X.shape)
print(len(y))
# Out:
# (2687, 7228)
# 2687

# %% [markdown]
# **Our Input Data**
# 1. The X matrix
# 2. The vectorizer
# 3. The y vector

# %% [markdown]
# Simple NB classifier for binary response variable -- the [documentation](https://scikit-learn.org/stable/modules/naive_bayes.html) is good -- be sure to read it!

# %%
from sklearn.naive_bayes import BernoulliNB
nb = BernoulliNB()
nb.fit(X,y)
# Out:
# BernoulliNB()

# %%
# Use the model to predict the value of all records in the training set
ypred = nb.predict(X)
print(len(ypred))
print(ypred)
# Out:
# 2687
# [1 1 1 ... 1 1 1]

# %%
# How many "good" predicitions are they, and how does that compare to actual y values?
from collections import Counter
print(Counter(ypred))
print(Counter(y))
# Out:
# Counter({1: 2491, 0: 196})
# Counter({1: 2316, 0: 371})

# %% [markdown]
# Various tools to measure prediction accuracy

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y, nb.predict(X)))
# Out:
# 0.8641607740975065

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# Confusion matrix -- argument order matters -- y is 
# down the rows because it is first.  Predicted is across the 
# columns because it is second.

print(confusion_matrix(y, nb.predict(X)))
print(accuracy_score(y, nb.predict(X)))

# Remember, this is training accuracy.  Bad if it's low, meaningless if it's high
# Out:
# [[ 101  270]
#  [  95 2221]]
# 0.8641607740975065

# %%
# Quick way to split our X and y into training and test pieces for measuring
# test accuracy

# The random_state argument seeds the random number generator so you get the
# same split each time.  Not random, but good for debugging

from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Just a method so we can evaluate a classifier easily

def eval_test_set(clf, xtrain, ytrain, xtest, ytest):
    clf.fit(xtrain, ytrain)
    print(confusion_matrix(ytest, clf.predict(xtest)))
    print(accuracy_score(ytest, clf.predict(xtest)))

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
eval_test_set(BernoulliNB(), xTrain, yTrain, xTest, yTest)
eval_test_set(MultinomialNB(), xTrain, yTrain, xTest, yTest)

#  Too bad, test accuracy is much worse than training accuracy
# Out:
# [[ 11  85]
#  [ 53 523]]
# 0.7946428571428571
# [[ 22  74]
#  [ 15 561]]
# 0.8675595238095238

# %% [markdown]
# **Cross-Fold Validation**

# %%
# Cross-fold validation -- this is 10-fold, split the X and y into 
# ten pieces, loop ten times, one for each piece:  train on the other 9, 
# then test on the 10th.   Average is estimate for test accuracy

from sklearn.model_selection import cross_val_score
def cross_validate(clf, x, y):
    return cross_val_score(clf, x, y, cv=10).mean()

# %%
def eval_classifier(clf, X, y):
    clf.fit(X,y)
    print(f"Results for {clf}")
    print(f"Cross validation mean accuracy: {cross_validate(clf, X, y)}")
    print(f"Training accuracy: {accuracy_score(y, clf.predict(X))}")
    print(confusion_matrix(y, clf.predict(X)))

# %%
from sklearn.naive_bayes import ComplementNB
print(cross_validate(BernoulliNB(), X, y))
print(cross_validate(MultinomialNB(), X, y))
print(cross_validate(ComplementNB(), X, y))

# This should be a little better than the holdback test accuracy
# because we get to use all the test data

# This is our baseline accuracy -- can we change preprocessing and/or get 
# rid of features to improve it?
# Out:
# 0.8191116906175442
# 0.8797841646784663
# 0.8768074127503744

# %%
eval_classifier(BernoulliNB(), X, y)
print()
eval_classifier(MultinomialNB(), X, y)
print()
eval_classifier(ComplementNB(), X, y)

# %% [markdown]
# **Other Options for a Classifier**
#
# How do these perform compared to our Naive Bayes baseline?
#
# 1. Rocchio (nearest centroid)
# 2. Nearest neighbor

# %%
from sklearn.neighbors import NearestCentroid
eval_classifier(NearestCentroid(), X,y)

# %%
from sklearn.neighbors import KNeighborsClassifier
eval_test_set(KNeighborsClassifier(n_neighbors=20), X,y)

# %%
# Here is apples-to-apples comparison of all models we have tried so far

print(f"Bernoulli Naive Bayes {cross_validate(BernoulliNB(), X, y)}")
print(f"Multinomial Naive Bayes {cross_validate(MultinomialNB(), X, y)}")
print(f"Complement Naive Bayes {cross_validate(ComplementNB(), X, y)}")
print(f"Nearest Centroid {cross_validate(NearestCentroid(), X,y)}")
print(f"Nearest neighbors (20) {cross_validate(KNeighborsClassifier(n_neighbors=20), X, y)}")
print(f"Nearest neighbors (5) {cross_validate(KNeighborsClassifier(n_neighbors=5), X, y)}")
print(f"Nearest neighbors (12) {cross_validate(KNeighborsClassifier(n_neighbors=12), X, y)}")

# %% [markdown]
# Tentative decision:  choose Multinomial Naive Bayes, reject Rocchio, and experiment to see how much we can improve KNN

# %% [markdown]
# **Hyperparameter Optimization**
#
# Nearest Neighbor is the only algorithm with a hyperparameter (number of neighbors)

# %%
from sklearn.model_selection import GridSearchCV

# Loop over number of neighbors, and compute cross-validated accuracy for each setting.
# Remember the parameter setting with the best accuracy.
# Notice that the result of GridSearchCV is also a classifier -- it has fit and predict methods

clf = GridSearchCV(KNeighborsClassifier(), {'n_neighbors': range(1,50,2)}, cv=10, scoring='accuracy')
clf.fit(X, y)

# %%
# Notice that the grid search is actually a classifier too!
clf.best_estimator_

# %%
clf.cv_results_

# %%
# Just for completeness, this is optimal accuracy for KNN.
print(f"Nearest neighbors (optimal) {cross_validate(clf, X, y)}")

# %%
#  There is an interesting curve relating number of neighbors to accuracy
#  This piece just collects (x,y) pairs where x is neighbors and y is accuracy,
#   so we can do a plot

neighbors = []
accuracies = []

for nn in range(1,100,2):
    neighbors.append(nn)
    accuracies.append(cross_validate(KNeighborsClassifier(n_neighbors=nn), X, y))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# (x,y) line plot of number of neighbors vs test accuracy
plt.style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()
ax.plot(neighbors, accuracies);
ax.set_xlabel('# Neighbors')
ax.set_ylabel("Accuracy")

# %%
# What value is the accuracy converging to?
Counter(y)[1]/ (Counter(y)[0]+Counter(y)[1])

# %% [markdown]
# ----------------------------------------------
# ### Feature Engineering
#
# Improve the algorithm by modifying the vectorizer, limiting features
#
# This all starts with the assumption that we will go with Naive Bayes as our classifier of choice
#
# 1.  See if we can improve the tokenizer -- TFIDF
#   1. We could try n-grams and stop words too, because the Vectorizer can do those for us
# 2.  See if we can limit features -- do it in the Vectorizer, and also try some more informed greedy methods like mutual information
# 3.  Examine the misclassifications to see if there's anything obviously wrong

# %% [markdown]
# * Variations on the vectorizer -- try just Count vs Tfidf
# * Other variants would be stemming, n-grams, stop words

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

b = MultinomialNB()

v = CountVectorizer()
X = v.fit_transform(reviews.text)
print(f"Count Vectorizer {cross_validate(b, X, y)}")

v = TfidfVectorizer()
X = v.fit_transform(reviews.text)
print(f"Tfidf Vectorizer {cross_validate(b, X, y)}")

# %%
# Try restricting out uncommon and super common words
v = CountVectorizer(min_df=2, max_df=.95)
X = v.fit_transform(reviews.text)
print(f"Count Vectorizer {cross_validate(b, X, y)}")

# %%
# Try bigrams
v = CountVectorizer(min_df=2, max_df=.95, ngram_range=(1,2))
X = v.fit_transform(reviews.text)
print(f"Count Vectorizer {cross_validate(b, X, y)}")

# %%
X.shape

# %% [markdown]
# ### Feature Selection by Mutual Information

# %% [markdown]
# #### Feature selection by mutual information measure

# %%
from sklearn.feature_selection import mutual_info_classif
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_selection
mutual_info_classif(X,y)

# %%
# Select K best
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html
from sklearn.feature_selection import SelectKBest
newX = SelectKBest(mutual_info_classif, k=100).fit_transform(X,y)
newX.shape

# %%
def k_features_x(k, X, y, fs=mutual_info_classif):
    kbest = SelectKBest(fs, k=k)
    return kbest.fit_transform(X, y)

#  Assess accuracy of the classifier after choosing k best features
def k_features_accuracy(k, clf, x, y, fs=mutual_info_classif):
    X_new = k_features_x(k, x, y, fs)
    return cross_validate(clf, X_new, y)

# %%
X = CountVectorizer(min_df=2, max_df=.95, ngram_range=(1,2)).fit_transform(reviews.text)
k_features_accuracy(5000, MultinomialNB(), X, y)

# %%
###########################
# Caution!!  This takes a very long time!

mnb = MultinomialNB()
v = CountVectorizer(min_df=2, max_df=.95, ngram_range=(1,2))
X = v.fit_transform(reviews.text)

#  Set up to plot accuracy as a function of k (number features)
xval = []
yval = []
for k in range(100, 4000, 400):
    print(k)
    xval.append(k)
    yval.append(k_features_accuracy(k, mnb, X, y))
for k in range(4000, X.shape[1], 500):
    print(k)
    xval.append(k)
    yval.append(k_features_accuracy(k, mnb, X, y))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig = plt.figure()
ax = plt.axes()
ax.plot(xval, yval);

# Nice plot with optimal number of features around 3000 (out of 14.8K!)

# %% [markdown]
# Sample plot of cross-val accuracy vs number of features
#
# ![Accuracy vs num features](accuracy_vs_num_features.png)

# %% [markdown]
# ### Classifier-Specific Feature Impact
#
# Since we are using Naive Bayes, the classifier itself has a measure of feature impact, through the ratio of P(term|class=0) / P(term|class=1).
#
# In that ratio, the highest value are the terms that are "most negative" and the lowest values are the terms that are "most positive" and a value of 1 means the term is irrelevant.
#
# This code shows the features that have the highest and lowest ratio.
#
# The question is whether this measure is better than mutual information for limiting # features

# %%
v = CountVectorizer(min_df=2, max_df=.95)
X = v.fit_transform(reviews.text)
b = MultinomialNB()
b.fit(X, y)

#v.get_feature_names()
b.feature_log_prob_

# %%
def log_prob_ratios(classifier):
    return classifier.feature_log_prob_[0] / classifier.feature_log_prob_[1]

# %%
sorted(list(log_prob_ratios(b)), reverse=True)[0:10]

# %%
def important_features(vectorizer,classifier,n=20):
    feature_names =vectorizer.get_feature_names()
    log_prob_frac = log_prob_ratios(classifier)
    frac_and_name_pos = sorted(zip(log_prob_frac, feature_names),reverse=True)[:n]
    frac_and_name_neg = sorted(zip(log_prob_frac, feature_names),reverse=False)[:n]   
    print(f"Important words POSITIVE")
    for coef, feat in frac_and_name_pos:
        print(coef, feat)
    print("==========")
    print(f"Important words NEGATIVE")
    for coef, feat in frac_and_name_neg:
        print(coef, feat)

# %%
v = CountVectorizer(min_df=2, max_df=.95)
X = v.fit_transform(reviews.text)
b = MultinomialNB()
b.fit(X, y)
important_features(v, b, n=20)

# %% [markdown]
# The SelectKBest feature selector can take a ranking function as an input -- previously we used the built-in ranker mutual information, but we can use the probability ratio instead.  In this case a feature is more significant the farther away from 1 it is.

# %%
# Signature is dictated by SelectKBest -- 
#  "Function taking two arrays X and y, and returning a pair of arrays (scores, pvalues) or a single array with scores"

# Returns a vector of scores for each feature based on the score ratio
def prob_ratio_score(X, y):
    b = MultinomialNB()
    b.fit(X, y)
    log_prob_frac = log_prob_ratios(b)
    return abs(log_prob_frac - 1.0)

# %%
#  Now we can select the K best features based on the ratio.  Just for a reality check:  
#  this transform should reduce the number of features from 14.8K to 2K
v = CountVectorizer(min_df=2, max_df=.95)
X = v.fit_transform(reviews.text)
kbest = SelectKBest(prob_ratio_score, k=2000)
XX = kbest.fit_transform(X, y)
print(X.shape)
print(XX.shape)

# %%
# And here is our head-to-head comparison.  Same classifier, same vectorizer, same 
#  number of features, but we just rank the features differently
v = CountVectorizer(min_df=2, max_df=.95)

print(k_features_accuracy(3000, MultinomialNB(), v.fit_transform(reviews.text), y))
print(k_features_accuracy(3000, MultinomialNB(), v.fit_transform(reviews.text), y, prob_ratio_score))

# %% [markdown]
# -------------------------------------------------------
#
# ### Examining Misclassified Instances
#
# 1. Find some misclassified instances
# 2. Visually, can we see anything that would make us worry or not worry?
# 3. If the reason for misclassification isn't obvious, look more closely at the words and their scores according to the classifier

# %%
# This is our baseline best classifier.
b = MultinomialNB()
v = CountVectorizer(min_df=2, max_df=.95)
X = v.fit_transform(reviews.text)
kbest = SelectKBest(prob_ratio_score, k=3000)
X = kbest.fit_transform(X, y)
eval_test_set(b, Xnew, y)

# %%
#  Get indices of some misclassified instances.  Remember that
#  the index (observation #) is the same in X, y
b.fit(X, y)
pred = b.predict(X)
mask = pred != np.array(y)
misclassed = np.array(list(zip(range(0,len(pred)), zip(y, pred))), dtype=object)
misclassed[mask]

# For example [167, (1, 0)] means that for example # 167, the actual value was 1 but we predicted 0

# %%
# Actual label is good (1), we classify bad (0)
raw_training[45]

# %%
b.predict_proba(X)[45]

# %%
kbest.get_support()

# %%
#  Get the fitted classifier's term probabilities -- i.e the ratio P(term|class=0) / P(term|class=1)
#  Remember that the classifier is working on a reduced set of features!
#  The vectorizer knows the term names, but it stores the larger set of features so we have to 
def feature_log_prob(b, v, k):
    # Select the feature names actually used by kbest
    feature_names = np.array(v.get_feature_names())[k.get_support()]
    log_prob_frac = b.feature_log_prob_[0] / b.feature_log_prob_[1]
    return dict(zip(feature_names, log_prob_frac))

# %%
#  Show the log prob ratio for the instance with this index.
#  NOTE -- this is using values of b (classifier), v(vectorizer), and kbest(X with reduced features)

def show_scores_for(index, b, v, k):
    # Mapping of term to log prob (all possible features)
    flp = feature_log_prob(b,v,k)
    # Feature names, only the k best
    feature_names = np.array(v.get_feature_names())[k.get_support()]
    # Term values (just a count) 
    termvals = X[index].toarray().ravel()
    scores = []
    for i in range(0, termvals.shape[0]):
        if termvals[i] > 0:
            scores.append((feature_names[i], termvals[i], flp[feature_names[i]]))
    return sorted(scores, key=lambda x: x[2])

# %%
show_scores_for(45, b, v, kbest)
# These are the term scores for the short review

# %%
# This is a misprediction where label is bad but we predicted good
b.predict_proba(Xnew)[817]

# %%
raw_training[817]

# %%
show_scores_for(817, b, v, kbest)
