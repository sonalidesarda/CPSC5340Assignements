# %% [markdown]
# ###  IntroLab -- TCSS 5340
#
# This introductory lab should get you started with the key techniques and technologies used in Assignment 0 and throughout the class
# * The Github repository
# * Jupyter notebooks
# * Text processing in Python
# * Good development methodology -- one step at a time, and test the smaller parts
#
# You will not hand anything in unless you want me to review your solution.  If you get stuck on any of the coding, just consult the solution and copy that piece in, but at the end be sure you understand the problem and solution end to end.
#
# The main task is to process a text file, which is the text version of a book.  You will break each file into words or "tokens" and report on the N most frequently occurring tokens.
#
# The main piece code will be a single function <pre>mostFrequentTokens(filename, n=10)</pre> that will read the file, convert file contents to tokens, count the number of occurrences of each token, then sort by count and return the N most frequent, along with the count for each.
#
# We will take it step by step, breaking the full task into small pieces and testing each piece

# %%
# The function readFile takes a filename as input and returns the document contents as a single string
def readFile(filename):
    ## YOUR CODE HERE

# %%
#  Test the function.  Notice this test is in a different cell from the 
#  function definition. NEVER put the code and the tests in the same cell!
readFile("austen-emma.txt")[0:99]
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with '

# %%
# Break the string into words.  Input is a (long) string. Output is a list of 'words', split on whitespace

def splitIntoWords(str):
    ## YOUR CODE HERE

# %%
# Test the first two functions.  The first returned word looks bad!  But don't worry, the 
# problem is just that the text actually contains brackets

splitIntoWords(readFile("austen-emma.txt"))[0:19]
# Out:
# ['[Emma',
#  'by',
#  'Jane',
#  'Austen',
#  '1816]',
#  'VOLUME',
#  'I',
#  'CHAPTER',
#  'I',
#  'Emma',
#  'Woodhouse,',
#  'handsome,',
#  'clever,',
#  'and',
#  'rich,',
#  'with',
#  'a',
#  'comfortable',
#  'home']

# %%
# 'Tokenize' the list of words.  To tokenize, remove all non-letters, and convert all letters to lower case

# Input -- a word (sequence of non-whitespace characters)
# Output -- a copy of the word with all non-letters removed and all letters converted to lower case
import re
def tokenizeWord(word):
    ## YOUR CODE HERE

# %%
# Test -- try tokenizing a whole book
[tokenizeWord(word) for word in splitIntoWords(readFile("austen-emma.txt"))][0:9]
# Out:
# ['emma', 'by', 'jane', 'austen', '', 'volume', 'i', 'chapter', 'i']

# %%
## Oops, tokenization can result in empty strings, which we don't want.  
#  To tokenize a file, we also need to filter those out
# This function reads the file, splits it into words, tokenizes the words, and removes empty tokens

def tokenizeFile(filename):
    # YOUR CODE HERE

# %%
# Test
tokenizeFile("austen-emma.txt")[0:19]
# Out:
# ['emma',
#  'by',
#  'jane',
#  'austen',
#  'volume',
#  'i',
#  'chapter',
#  'i',
#  'emma',
#  'woodhouse',
#  'handsome',
#  'clever',
#  'and',
#  'rich',
#  'with',
#  'a',
#  'comfortable',
#  'home',
#  'and']

# %%
# Compute the count for each token.
# Input is a list of tokens.  Output is a dictionary -- key is a token, value is the count
from collections import Counter
def countTokens(tokenList):
    # YOUR CODE HERE

# %%
# Test
countTokens(tokenizeFile("austen-emma.txt"))
# Out:
# {'emma': 751,
#  'by': 567,
#  'jane': 272,
#  'austen': 1,
#  'volume': 3,
#  'i': 2968,
#  'chapter': 56,
#  'woodhouse': 263,
#  'handsome': 34,
#  'clever': 26,
#  'and': 4613,
#  'rich': 14,
#  'with': 1208,
#  'a': 3073,
#  'comfortable': 34,
#  'home': 124,
#  'happy': 120,
#  'disposition': 24,
#  'seemed': 140,
#  'to': 5149,
#  'unite': 3,
#  'some': 262,
#  'of': 4274,
#  'the': 5146,
#  'best': 82,
#  'blessings': 6,
#  'existence': 5,
#  'had': 1618,
#  'lived': 25,
#  'nearly': 14,
#  'twentyone': 1,
#  'years': 55,
#  'in': 2147,
#  'world': 76,
#  'very': 1187,
#  'little': 361,
#  'distress': 19,
#  'or': 477,
#  'vex': 1,
#  'her': 2417,
#  'she': 2278,
#  'was': 2376,
#  'youngest': 4,
#  'two': 173,
#  'daughters': 21,
#  'most': 247,
#  'affectionate': 9,
#  'indulgent': 1,
#  'father': 156,
#  'consequence': 26,
#  'sisters': 18,
#  'marriage': 34,
#  'been': 755,
#  'mistress': 10,
#  'his': 1137,
#  'house': 89,
#  'from': 542,
#  'early': 41,
# ...

# %%
# Input:  name of the file, and number of elements to return
# Output:  list of length N (or fewer) of pairs of the form (token, count) sorted in descending order of count

def mostFrequentTokens(filename, n=10):
    # YOUR CODE HERE

# %%
mostFrequentTokens("austen-emma.txt", n=5)
# Out:
# [('to', 5149), ('the', 5146), ('and', 4613), ('of', 4274), ('a', 3073)]
